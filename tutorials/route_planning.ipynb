# %% [markdown]
# In this tutorial, we'll demonstrate the Argoverse 2.0 map API, and visualize some of the map data.

# %%
from argparse import Namespace

"""Unit tests on utilities for converting AV2 city coordinates to UTM or WGS84 coordinate systems."""

# %matplotlib qt
import matplotlib.pyplot as plt
import numpy as np
from av2.geometry.utm import CityName
from pathlib import Path
from av2.map.map_api import ArgoverseStaticMap, LaneSegment

# %% [markdown]
# ### Import functions from other modules

# %%
from av2.utils.utils import create_argoverse_static_map, get_city_enum_from_cityname
from av2.utils.utils import convert_city_coords_to_wgs84, ndarray_to_two_lists, convert_wgs84_points_to_city_coords
from av2.utils.utils import plot_coordinates_on_map, plot_route_and_correct, plot_and_save_plt

# %% [markdown]
# ### Organizing scenarios:
# Folder structure:
# - /data1/av2-goro
#     - MIA
#     - PIT
#     - ATX
#     - DTW
#     - WDC
#     - PAO
# Read three categories under `dataroot`

# %%
import os 
import shutil, errno

def copy(src, dst):
    # Avoid if dst already exist.
    if os.path.exists(dst):
        print(f"path {dst} already existed.")
        return
    try:
        shutil.copytree(src, dst)    
    except OSError as exc: # python >2.5
        if exc.errno in (errno.ENOTDIR, errno.EINVAL):
            shutil.copy(src, dst)
        else: raise

# Sample log_map_path: /data1/av2-datasets/train/00a6ffc1-6ce9-3bc3-a060-6006e9893a1a/map/0a8a4cfa-4902-3a76-8301-08698d6290a2_ground_height_surface____PIT.npy
def extract_cityname_from_log(dataroot, log_id):
    log_map_dirpath = Path(dataroot) / log_id / "map" 
    npy_files = list(log_map_dirpath.glob("*.npy"))
    if len(npy_files) >1:
        print(f"ERROR! log_id {log_id} contains multiple npy file. Can't extract CityName")
    for npy_file in npy_files:
        cityname = str(npy_file)[-7:-4]
    return cityname


dataroot = "/data1/av2"
new_dataroot = "/data1/av2-goro"

CITY_NAMES={'MIA', 'PIT', 'ATX', 'DTW','WDC', 'PAO'}
# First create these folders
for name in CITY_NAMES:
    new_path = os.path.join(new_dataroot, name)
    if not os.path.exists(new_path):
        os.mkdir(new_path)

train_dir = os.path.join(dataroot, 'train')
test_dir = os.path.join(dataroot, 'test')
val_dir = os.path.join(dataroot, 'val')
directories = [train_dir, test_dir, val_dir]

log_to_cityname = {}

for directory in directories: # train, test, val
    for log_id in os.listdir(directory):
        cityname = extract_cityname_from_log(directory, log_id)
        log_to_cityname[log_id] = cityname
        # copy entier folder (entry) to new_path
        new_path = Path(new_dataroot) / cityname / log_id / "map" 
        src = Path(dataroot) / directory / log_id / "map" 
        print(f"Copying {src} to {new_path}...")
        copy(src, new_path)
    
Total_num_logs = 0
for name in CITY_NAMES:
    new_path = os.path.join(new_dataroot, name)
    if os.path.exists(new_path):
        num_logs = len(os.listdir(new_path))
        print(f"{name}: {num_logs} scenarios")
        Total_num_logs += num_logs   
print(f"Total number of scenarios: {Total_num_logs}")
# Out:
# Copying /data1/av2/train/adc1fad7-de31-371f-810b-140576d9accc/map to /data1/av2-goro/MIA/adc1fad7-de31-371f-810b-140576d9accc/map...
# path /data1/av2-goro/MIA/adc1fad7-de31-371f-810b-140576d9accc/map already existed.
# Copying /data1/av2/train/e4279e3e-b7e1-3f43-aeef-2bfa2836dab6/map to /data1/av2-goro/PIT/e4279e3e-b7e1-3f43-aeef-2bfa2836dab6/map...
# path /data1/av2-goro/PIT/e4279e3e-b7e1-3f43-aeef-2bfa2836dab6/map already existed.
# Copying /data1/av2/train/aa82b61f-7156-3c68-95a4-b79cebd120eb/map to /data1/av2-goro/MIA/aa82b61f-7156-3c68-95a4-b79cebd120eb/map...
# path /data1/av2-goro/MIA/aa82b61f-7156-3c68-95a4-b79cebd120eb/map already existed.
# Copying /data1/av2/train/f54c1d50-48a3-4651-bfb0-50b87f13dc9e/map to /data1/av2-goro/MIA/f54c1d50-48a3-4651-bfb0-50b87f13dc9e/map...
# path /data1/av2-goro/MIA/f54c1d50-48a3-4651-bfb0-50b87f13dc9e/map already existed.
# Copying /data1/av2/train/cf6a99cb-b8bc-34d7-bdca-30e50e66cd74/map to /data1/av2-goro/ATX/cf6a99cb-b8bc-34d7-bdca-30e50e66cd74/map...
# path /data1/av2-goro/ATX/cf6a99cb-b8bc-34d7-bdca-30e50e66cd74/map already existed.
# Copying /data1/av2/train/d0828f48-3e67-3136-9c70-1f99968c8280/map to /data1/av2-goro/PIT/d0828f48-3e67-3136-9c70-1f99968c8280/map...
# path /data1/av2-goro/PIT/d0828f48-3e67-3136-9c70-1f99968c8280/map already existed.
# Copying /data1/av2/train/be94abe3-f84c-34d6-8461-3105bcfcedb7/map to /data1/av2-goro/MIA/be94abe3-f84c-34d6-8461-3105bcfcedb7/map...
# path /data1/av2-goro/MIA/be94abe3-f84c-34d6-8461-3105bcfcedb7/map already existed.
# Copying /data1/av2/train/8bc34c99-1b8f-3463-b0e7-12bf1eb222b3/map to /data1/av2-goro/DTW/8bc34c99-1b8f-3463-b0e7-12bf1eb222b3/map...
# path /data1/av2-goro/DTW/8bc34c99-1b8f-3463-b0e7-12bf1eb222b3/map already existed.
# Copying /data1/av2/train/b21b7285-2199-3264-b10a-524e9b23502a/map to /data1/av2-goro/PIT/b21b7285-2199-3264-b10a-524e9b23502a/map...
# path /data1/av2-goro/PIT/b21b7285-2199-3264-b10a-524e9b23502a/map already existed.
# Copying /data1/av2/train/5fe10166-ab1e-36d5-aa2b-c0d6f680f2c7/map to /data1/av2-goro/PIT/5fe10166-ab1e-36d5-aa2b-c0d6f680f2c7/map...
# path /data1/av2-goro/PIT/5fe10166-ab1e-36d5-aa2b-c0d6f680f2c7/map already existed.
# Copying /data1/av2/train/bdd7e8ba-f7fa-38d1-b6bf-9dc77334fec5/map to /data1/av2-goro/PIT/bdd7e8ba-f7fa-38d1-b6bf-9dc77334fec5/map...
# path /data1/av2-goro/PIT/bdd7e8ba-f7fa-38d1-b6bf-9dc77334fec5/map already existed.
# Copying /data1/av2/train/23808d42-e4df-3a0d-b713-fe20e09a4f39/map to /data1/av2-goro/MIA/23808d42-e4df-3a0d-b713-fe20e09a4f39/map...
# path /data1/av2-goro/MIA/23808d42-e4df-3a0d-b713-fe20e09a4f39/map already existed.
# Copying /data1/av2/train/76038978-47aa-30ed-bfa1-2d63753a866c/map to /data1/av2-goro/PIT/76038978-47aa-30ed-bfa1-2d63753a866c/map...
# path /data1/av2-goro/PIT/76038978-47aa-30ed-bfa1-2d63753a866c/map already existed.
# Copying /data1/av2/train/0b97f5dd-c396-3c02-b07d-b7fdbcb6c3d0/map to /data1/av2-goro/MIA/0b97f5dd-c396-3c02-b07d-b7fdbcb6c3d0/map...
# path /data1/av2-goro/MIA/0b97f5dd-c396-3c02-b07d-b7fdbcb6c3d0/map already existed.
# Copying /data1/av2/train/3b2994cb-5f82-4835-9212-0cac8fb3d164/map to /data1/av2-goro/MIA/3b2994cb-5f82-4835-9212-0cac8fb3d164/map...
# path /data1/av2-goro/MIA/3b2994cb-5f82-4835-9212-0cac8fb3d164/map already existed.
# Copying /data1/av2/train/fa708289-f2b2-399e-989e-53f83fa379c5/map to /data1/av2-goro/DTW/fa708289-f2b2-399e-989e-53f83fa379c5/map...
# path /data1/av2-goro/DTW/fa708289-f2b2-399e-989e-53f83fa379c5/map already existed.
# Copying /data1/av2/train/28617035-7557-3cb9-99c2-754f72fd34b4/map to /data1/av2-goro/PIT/28617035-7557-3cb9-99c2-754f72fd34b4/map...
# path /data1/av2-goro/PIT/28617035-7557-3cb9-99c2-754f72fd34b4/map already existed.
# Copying /data1/av2/train/eec8ae97-8de4-354a-b11a-d3a14b276479/map to /data1/av2-goro/MIA/eec8ae97-8de4-354a-b11a-d3a14b276479/map...
# path /data1/av2-goro/MIA/eec8ae97-8de4-354a-b11a-d3a14b276479/map already existed.
# Copying /data1/av2/train/d3efe9ba-f10a-35e7-b17e-6850c66693fe/map to /data1/av2-goro/DTW/d3efe9ba-f10a-35e7-b17e-6850c66693fe/map...
# path /data1/av2-goro/DTW/d3efe9ba-f10a-35e7-b17e-6850c66693fe/map already existed.
# Copying /data1/av2/train/4690ea1e-224a-35e9-a984-8332295f2b00/map to /data1/av2-goro/PIT/4690ea1e-224a-35e9-a984-8332295f2b00/map...
# path /data1/av2-goro/PIT/4690ea1e-224a-35e9-a984-8332295f2b00/map already existed.
# Copying /data1/av2/train/f2b0585b-ada3-3123-963e-14df7d96ca9e/map to /data1/av2-goro/MIA/f2b0585b-ada3-3123-963e-14df7d96ca9e/map...
# path /data1/av2-goro/MIA/f2b0585b-ada3-3123-963e-14df7d96ca9e/map already existed.
# Copying /data1/av2/train/afbdd2e0-696a-3222-a20a-2023baf8e5af/map to /data1/av2-goro/MIA/afbdd2e0-696a-3222-a20a-2023baf8e5af/map...
# path /data1/av2-goro/MIA/afbdd2e0-696a-3222-a20a-2023baf8e5af/map already existed.
# Copying /data1/av2/train/c990cafc-f96c-3107-b213-01d217b11272/map to /data1/av2-goro/PIT/c990cafc-f96c-3107-b213-01d217b11272/map...
# path /data1/av2-goro/PIT/c990cafc-f96c-3107-b213-01d217b11272/map already existed.
# Copying /data1/av2/train/4977e8a8-4e1f-3ca2-a44e-454cd3756a5f/map to /data1/av2-goro/MIA/4977e8a8-4e1f-3ca2-a44e-454cd3756a5f/map...
# path /data1/av2-goro/MIA/4977e8a8-4e1f-3ca2-a44e-454cd3756a5f/map already existed.
# Copying /data1/av2/train/74648e09-358d-3183-9b40-278620befa40/map to /data1/av2-goro/PIT/74648e09-358d-3183-9b40-278620befa40/map...
# path /data1/av2-goro/PIT/74648e09-358d-3183-9b40-278620befa40/map already existed.
# Copying /data1/av2/train/d5d40b4c-48d9-3b68-903a-025eb0fa334d/map to /data1/av2-goro/PIT/d5d40b4c-48d9-3b68-903a-025eb0fa334d/map...
# path /data1/av2-goro/PIT/d5d40b4c-48d9-3b68-903a-025eb0fa334d/map already existed.
# Copying /data1/av2/train/067b1c50-6567-3840-ab56-1ca2a0ed9c30/map to /data1/av2-goro/PIT/067b1c50-6567-3840-ab56-1ca2a0ed9c30/map...
# path /data1/av2-goro/PIT/067b1c50-6567-3840-ab56-1ca2a0ed9c30/map already existed.
# Copying /data1/av2/train/5d8f4b0a-27f8-3889-925f-e9a146a395eb/map to /data1/av2-goro/ATX/5d8f4b0a-27f8-3889-925f-e9a146a395eb/map...
# path /data1/av2-goro/ATX/5d8f4b0a-27f8-3889-925f-e9a146a395eb/map already existed.
# Copying /data1/av2/train/9a372faa-e598-30e2-999f-99f90a0b099e/map to /data1/av2-goro/MIA/9a372faa-e598-30e2-999f-99f90a0b099e/map...
# path /data1/av2-goro/MIA/9a372faa-e598-30e2-999f-99f90a0b099e/map already existed.
# Copying /data1/av2/train/fdc0f552-4976-36a6-8691-9a8c6a5ba389/map to /data1/av2-goro/WDC/fdc0f552-4976-36a6-8691-9a8c6a5ba389/map...
# path /data1/av2-goro/WDC/fdc0f552-4976-36a6-8691-9a8c6a5ba389/map already existed.
# Copying /data1/av2/train/1e51a567-b416-3c46-9424-05688ff851f7/map to /data1/av2-goro/MIA/1e51a567-b416-3c46-9424-05688ff851f7/map...
# path /data1/av2-goro/MIA/1e51a567-b416-3c46-9424-05688ff851f7/map already existed.
# Copying /data1/av2/train/6b14d7c0-20f9-390b-af38-507a5de5998c/map to /data1/av2-goro/MIA/6b14d7c0-20f9-390b-af38-507a5de5998c/map...
# path /data1/av2-goro/MIA/6b14d7c0-20f9-390b-af38-507a5de5998c/map already existed.
# Copying /data1/av2/train/40870b19-3356-3e8e-a4a4-9f34eef8ea30/map to /data1/av2-goro/WDC/40870b19-3356-3e8e-a4a4-9f34eef8ea30/map...
# path /data1/av2-goro/WDC/40870b19-3356-3e8e-a4a4-9f34eef8ea30/map already existed.
# Copying /data1/av2/train/4667e48c-4d16-38be-b277-6b0013d6588c/map to /data1/av2-goro/DTW/4667e48c-4d16-38be-b277-6b0013d6588c/map...
# path /data1/av2-goro/DTW/4667e48c-4d16-38be-b277-6b0013d6588c/map already existed.
# Copying /data1/av2/train/285dcef7-9f00-3c9c-baca-6c8269210ac4/map to /data1/av2-goro/MIA/285dcef7-9f00-3c9c-baca-6c8269210ac4/map...
# path /data1/av2-goro/MIA/285dcef7-9f00-3c9c-baca-6c8269210ac4/map already existed.
# Copying /data1/av2/train/b4fc7eef-819c-35a6-b937-358ffb5c2aa0/map to /data1/av2-goro/MIA/b4fc7eef-819c-35a6-b937-358ffb5c2aa0/map...
# path /data1/av2-goro/MIA/b4fc7eef-819c-35a6-b937-358ffb5c2aa0/map already existed.
# Copying /data1/av2/train/988ab841-c422-3d08-bb52-a09f8fdb6ab2/map to /data1/av2-goro/PIT/988ab841-c422-3d08-bb52-a09f8fdb6ab2/map...
# path /data1/av2-goro/PIT/988ab841-c422-3d08-bb52-a09f8fdb6ab2/map already existed.
# Copying /data1/av2/train/46d917cd-531c-330b-8d7b-979b51a8927f/map to /data1/av2-goro/PIT/46d917cd-531c-330b-8d7b-979b51a8927f/map...
# path /data1/av2-goro/PIT/46d917cd-531c-330b-8d7b-979b51a8927f/map already existed.
# Copying /data1/av2/train/bb9be2e6-8f0e-3bb3-8bb9-5d9aa9df384d/map to /data1/av2-goro/PIT/bb9be2e6-8f0e-3bb3-8bb9-5d9aa9df384d/map...
# path /data1/av2-goro/PIT/bb9be2e6-8f0e-3bb3-8bb9-5d9aa9df384d/map already existed.
# Copying /data1/av2/train/20f785b0-e11a-3757-be79-b0731286c998/map to /data1/av2-goro/PIT/20f785b0-e11a-3757-be79-b0731286c998/map...
# path /data1/av2-goro/PIT/20f785b0-e11a-3757-be79-b0731286c998/map already existed.
# Copying /data1/av2/train/e66d1403-755b-3f63-938b-a2a69446a48a/map to /data1/av2-goro/ATX/e66d1403-755b-3f63-938b-a2a69446a48a/map...
# path /data1/av2-goro/ATX/e66d1403-755b-3f63-938b-a2a69446a48a/map already existed.
# Copying /data1/av2/train/1d950a38-5c2f-39ce-9cd3-61249bc85194/map to /data1/av2-goro/MIA/1d950a38-5c2f-39ce-9cd3-61249bc85194/map...
# path /data1/av2-goro/MIA/1d950a38-5c2f-39ce-9cd3-61249bc85194/map already existed.
# Copying /data1/av2/train/93582b51-5be1-30cd-abb0-3eac16dd6dbc/map to /data1/av2-goro/PIT/93582b51-5be1-30cd-abb0-3eac16dd6dbc/map...
# path /data1/av2-goro/PIT/93582b51-5be1-30cd-abb0-3eac16dd6dbc/map already existed.
# Copying /data1/av2/train/06e5ac08-f4cb-34ae-9406-3496f7cadc62/map to /data1/av2-goro/WDC/06e5ac08-f4cb-34ae-9406-3496f7cadc62/map...
# path /data1/av2-goro/WDC/06e5ac08-f4cb-34ae-9406-3496f7cadc62/map already existed.
# Copying /data1/av2/train/6f2f7d1e-8ded-35c5-ba83-3ca906b05127/map to /data1/av2-goro/PIT/6f2f7d1e-8ded-35c5-ba83-3ca906b05127/map...
# path /data1/av2-goro/PIT/6f2f7d1e-8ded-35c5-ba83-3ca906b05127/map already existed.
# Copying /data1/av2/train/189c8512-b034-3d58-a372-cf48eacf02dd/map to /data1/av2-goro/MIA/189c8512-b034-3d58-a372-cf48eacf02dd/map...
# path /data1/av2-goro/MIA/189c8512-b034-3d58-a372-cf48eacf02dd/map already existed.
# Copying /data1/av2/train/6aa2ac89-6b25-3af6-ad59-221351189f4b/map to /data1/av2-goro/MIA/6aa2ac89-6b25-3af6-ad59-221351189f4b/map...
# path /data1/av2-goro/MIA/6aa2ac89-6b25-3af6-ad59-221351189f4b/map already existed.
# Copying /data1/av2/train/271f4204-dd77-350b-b9db-5dabc4191985/map to /data1/av2-goro/DTW/271f4204-dd77-350b-b9db-5dabc4191985/map...
# path /data1/av2-goro/DTW/271f4204-dd77-350b-b9db-5dabc4191985/map already existed.
# Copying /data1/av2/train/087695bd-c662-3e86-83b4-aedc3b8eec36/map to /data1/av2-goro/PIT/087695bd-c662-3e86-83b4-aedc3b8eec36/map...
# path /data1/av2-goro/PIT/087695bd-c662-3e86-83b4-aedc3b8eec36/map already existed.
# Copying /data1/av2/train/2451c219-3002-3b2e-8fa9-2b7fea168b3b/map to /data1/av2-goro/PIT/2451c219-3002-3b2e-8fa9-2b7fea168b3b/map...
# path /data1/av2-goro/PIT/2451c219-3002-3b2e-8fa9-2b7fea168b3b/map already existed.
# Copying /data1/av2/train/539b7a79-54c6-30ef-8e06-210d42c79125/map to /data1/av2-goro/MIA/539b7a79-54c6-30ef-8e06-210d42c79125/map...
# path /data1/av2-goro/MIA/539b7a79-54c6-30ef-8e06-210d42c79125/map already existed.
# Copying /data1/av2/train/bb110668-5037-3c04-bd34-34cf1ace8d0f/map to /data1/av2-goro/ATX/bb110668-5037-3c04-bd34-34cf1ace8d0f/map...
# path /data1/av2-goro/ATX/bb110668-5037-3c04-bd34-34cf1ace8d0f/map already existed.
# Copying /data1/av2/train/dad3e145-2f70-357f-813e-703936927fe2/map to /data1/av2-goro/PIT/dad3e145-2f70-357f-813e-703936927fe2/map...
# path /data1/av2-goro/PIT/dad3e145-2f70-357f-813e-703936927fe2/map already existed.
# Copying /data1/av2/train/855ba280-cd69-348d-9107-69e28cb8ad99/map to /data1/av2-goro/PIT/855ba280-cd69-348d-9107-69e28cb8ad99/map...
# path /data1/av2-goro/PIT/855ba280-cd69-348d-9107-69e28cb8ad99/map already existed.
# Copying /data1/av2/train/12c3c14b-9cf2-3434-9a5d-e0bfa332f6ce/map to /data1/av2-goro/WDC/12c3c14b-9cf2-3434-9a5d-e0bfa332f6ce/map...
# path /data1/av2-goro/WDC/12c3c14b-9cf2-3434-9a5d-e0bfa332f6ce/map already existed.
# Copying /data1/av2/train/f4c6ade0-7b9e-4ad7-8d86-13d2f4c91499/map to /data1/av2-goro/MIA/f4c6ade0-7b9e-4ad7-8d86-13d2f4c91499/map...
# path /data1/av2-goro/MIA/f4c6ade0-7b9e-4ad7-8d86-13d2f4c91499/map already existed.
# Copying /data1/av2/train/b66a9b8e-8fa8-3409-907f-a70ebd7051e1/map to /data1/av2-goro/MIA/b66a9b8e-8fa8-3409-907f-a70ebd7051e1/map...
# path /data1/av2-goro/MIA/b66a9b8e-8fa8-3409-907f-a70ebd7051e1/map already existed.
# Copying /data1/av2/train/919f13de-857f-3b1c-9f8e-7cbe500a60ae/map to /data1/av2-goro/WDC/919f13de-857f-3b1c-9f8e-7cbe500a60ae/map...
# path /data1/av2-goro/WDC/919f13de-857f-3b1c-9f8e-7cbe500a60ae/map already existed.
# Copying /data1/av2/train/2a9b2658-097e-3f8b-a817-22f2553c5de8/map to /data1/av2-goro/DTW/2a9b2658-097e-3f8b-a817-22f2553c5de8/map...
# path /data1/av2-goro/DTW/2a9b2658-097e-3f8b-a817-22f2553c5de8/map already existed.
# Copying /data1/av2/train/32edd7c7-8a8f-360d-bcda-83ecf431e3e6/map to /data1/av2-goro/PIT/32edd7c7-8a8f-360d-bcda-83ecf431e3e6/map...
# path /data1/av2-goro/PIT/32edd7c7-8a8f-360d-bcda-83ecf431e3e6/map already existed.
# Copying /data1/av2/train/69c0ec7c-e289-3c4d-ade3-d2287ec34026/map to /data1/av2-goro/DTW/69c0ec7c-e289-3c4d-ade3-d2287ec34026/map...
# path /data1/av2-goro/DTW/69c0ec7c-e289-3c4d-ade3-d2287ec34026/map already existed.
# Copying /data1/av2/train/c6c55112-0078-3867-a63f-1861a0125b8d/map to /data1/av2-goro/DTW/c6c55112-0078-3867-a63f-1861a0125b8d/map...
# path /data1/av2-goro/DTW/c6c55112-0078-3867-a63f-1861a0125b8d/map already existed.
# Copying /data1/av2/train/382dfbe0-836e-385c-86f2-f1afcf57a402/map to /data1/av2-goro/MIA/382dfbe0-836e-385c-86f2-f1afcf57a402/map...
# path /data1/av2-goro/MIA/382dfbe0-836e-385c-86f2-f1afcf57a402/map already existed.
# Copying /data1/av2/train/67d5fb0a-baf8-32f4-9316-18ce755f3e8b/map to /data1/av2-goro/MIA/67d5fb0a-baf8-32f4-9316-18ce755f3e8b/map...
# path /data1/av2-goro/MIA/67d5fb0a-baf8-32f4-9316-18ce755f3e8b/map already existed.
# Copying /data1/av2/train/9f6d282e-f573-31d5-80e6-9a193e80cd7d/map to /data1/av2-goro/MIA/9f6d282e-f573-31d5-80e6-9a193e80cd7d/map...
# path /data1/av2-goro/MIA/9f6d282e-f573-31d5-80e6-9a193e80cd7d/map already existed.
# Copying /data1/av2/train/382cf8af-6c8d-3ed9-907b-12214d2c7cb0/map to /data1/av2-goro/PIT/382cf8af-6c8d-3ed9-907b-12214d2c7cb0/map...
# path /data1/av2-goro/PIT/382cf8af-6c8d-3ed9-907b-12214d2c7cb0/map already existed.
# Copying /data1/av2/train/2b6d18dc-4c95-3301-a498-3ed152798d5b/map to /data1/av2-goro/WDC/2b6d18dc-4c95-3301-a498-3ed152798d5b/map...
# path /data1/av2-goro/WDC/2b6d18dc-4c95-3301-a498-3ed152798d5b/map already existed.
# Copying /data1/av2/train/ff52c01e-3d7b-32b1-b6a1-bcff3459ccdd/map to /data1/av2-goro/WDC/ff52c01e-3d7b-32b1-b6a1-bcff3459ccdd/map...
# path /data1/av2-goro/WDC/ff52c01e-3d7b-32b1-b6a1-bcff3459ccdd/map already existed.
# Copying /data1/av2/train/dbe19bf6-93ad-372e-b96d-f7b652cdba93/map to /data1/av2-goro/PIT/dbe19bf6-93ad-372e-b96d-f7b652cdba93/map...
# path /data1/av2-goro/PIT/dbe19bf6-93ad-372e-b96d-f7b652cdba93/map already existed.
# Copying /data1/av2/train/7ca43466-7107-33ae-95d6-26d7af132e87/map to /data1/av2-goro/PIT/7ca43466-7107-33ae-95d6-26d7af132e87/map...
# path /data1/av2-goro/PIT/7ca43466-7107-33ae-95d6-26d7af132e87/map already existed.
# Copying /data1/av2/train/e125bb91-dcaf-3013-9cc7-da653d7e11e1/map to /data1/av2-goro/PIT/e125bb91-dcaf-3013-9cc7-da653d7e11e1/map...
# path /data1/av2-goro/PIT/e125bb91-dcaf-3013-9cc7-da653d7e11e1/map already existed.
# Copying /data1/av2/train/41b6f7d7-e431-3992-b783-74b9edf42215/map to /data1/av2-goro/MIA/41b6f7d7-e431-3992-b783-74b9edf42215/map...
# path /data1/av2-goro/MIA/41b6f7d7-e431-3992-b783-74b9edf42215/map already existed.
# Copying /data1/av2/train/6937b4e5-b5b4-3970-b5dd-9ad194e6c338/map to /data1/av2-goro/MIA/6937b4e5-b5b4-3970-b5dd-9ad194e6c338/map...
# path /data1/av2-goro/MIA/6937b4e5-b5b4-3970-b5dd-9ad194e6c338/map already existed.
# Copying /data1/av2/train/0c61aea3-3cba-35f3-8971-df42cd5b9b1a/map to /data1/av2-goro/PIT/0c61aea3-3cba-35f3-8971-df42cd5b9b1a/map...
# path /data1/av2-goro/PIT/0c61aea3-3cba-35f3-8971-df42cd5b9b1a/map already existed.
# Copying /data1/av2/train/b9f73e2a-292a-3876-b363-3ebb94584c7a/map to /data1/av2-goro/PIT/b9f73e2a-292a-3876-b363-3ebb94584c7a/map...
# path /data1/av2-goro/PIT/b9f73e2a-292a-3876-b363-3ebb94584c7a/map already existed.
# Copying /data1/av2/train/13209193-55c7-3827-917e-e04460b8f49b/map to /data1/av2-goro/DTW/13209193-55c7-3827-917e-e04460b8f49b/map...
# path /data1/av2-goro/DTW/13209193-55c7-3827-917e-e04460b8f49b/map already existed.
# Copying /data1/av2/train/7ef4a6cc-7266-3a31-8dd4-01c3d3c58dcb/map to /data1/av2-goro/MIA/7ef4a6cc-7266-3a31-8dd4-01c3d3c58dcb/map...
# path /data1/av2-goro/MIA/7ef4a6cc-7266-3a31-8dd4-01c3d3c58dcb/map already existed.
# Copying /data1/av2/train/1d43ed4e-e705-308a-bdfa-49d99285c42a/map to /data1/av2-goro/PIT/1d43ed4e-e705-308a-bdfa-49d99285c42a/map...
# path /data1/av2-goro/PIT/1d43ed4e-e705-308a-bdfa-49d99285c42a/map already existed.
# Copying /data1/av2/train/737314f0-997a-3cd1-a652-78453bfe2b57/map to /data1/av2-goro/MIA/737314f0-997a-3cd1-a652-78453bfe2b57/map...
# path /data1/av2-goro/MIA/737314f0-997a-3cd1-a652-78453bfe2b57/map already existed.
# Copying /data1/av2/train/07e4fccb-eb2d-31e5-bbcb-6550d0860f64/map to /data1/av2-goro/MIA/07e4fccb-eb2d-31e5-bbcb-6550d0860f64/map...
# path /data1/av2-goro/MIA/07e4fccb-eb2d-31e5-bbcb-6550d0860f64/map already existed.
# Copying /data1/av2/train/c67a748c-1e93-3a6d-be38-daedf175f911/map to /data1/av2-goro/MIA/c67a748c-1e93-3a6d-be38-daedf175f911/map...
# path /data1/av2-goro/MIA/c67a748c-1e93-3a6d-be38-daedf175f911/map already existed.
# Copying /data1/av2/train/6ee14358-31cb-3c6d-82f5-54d6a20444de/map to /data1/av2-goro/MIA/6ee14358-31cb-3c6d-82f5-54d6a20444de/map...
# path /data1/av2-goro/MIA/6ee14358-31cb-3c6d-82f5-54d6a20444de/map already existed.
# Copying /data1/av2/train/99a3270d-c5c5-3df7-9a2d-a612c8104d0e/map to /data1/av2-goro/PIT/99a3270d-c5c5-3df7-9a2d-a612c8104d0e/map...
# path /data1/av2-goro/PIT/99a3270d-c5c5-3df7-9a2d-a612c8104d0e/map already existed.
# Copying /data1/av2/train/713ac3dd-8777-373d-b87d-f3dd9820320e/map to /data1/av2-goro/PIT/713ac3dd-8777-373d-b87d-f3dd9820320e/map...
# path /data1/av2-goro/PIT/713ac3dd-8777-373d-b87d-f3dd9820320e/map already existed.
# Copying /data1/av2/train/a88da814-ecc6-39c0-93ba-8a81f403a7e4/map to /data1/av2-goro/MIA/a88da814-ecc6-39c0-93ba-8a81f403a7e4/map...
# path /data1/av2-goro/MIA/a88da814-ecc6-39c0-93ba-8a81f403a7e4/map already existed.
# Copying /data1/av2/train/26daba71-ca0a-37e9-9dc6-0f81f02c0afd/map to /data1/av2-goro/MIA/26daba71-ca0a-37e9-9dc6-0f81f02c0afd/map...
# path /data1/av2-goro/MIA/26daba71-ca0a-37e9-9dc6-0f81f02c0afd/map already existed.
# Copying /data1/av2/train/a47ba6a9-ffa1-3979-bb40-512339284b8b/map to /data1/av2-goro/PIT/a47ba6a9-ffa1-3979-bb40-512339284b8b/map...
# path /data1/av2-goro/PIT/a47ba6a9-ffa1-3979-bb40-512339284b8b/map already existed.
# Copying /data1/av2/train/f84b4941-8e99-3957-b6f6-db1590338cf6/map to /data1/av2-goro/WDC/f84b4941-8e99-3957-b6f6-db1590338cf6/map...
# path /data1/av2-goro/WDC/f84b4941-8e99-3957-b6f6-db1590338cf6/map already existed.
# Copying /data1/av2/train/2fff4135-98ec-3b82-a330-b73d8afdf36c/map to /data1/av2-goro/WDC/2fff4135-98ec-3b82-a330-b73d8afdf36c/map...
# path /data1/av2-goro/WDC/2fff4135-98ec-3b82-a330-b73d8afdf36c/map already existed.
# Copying /data1/av2/train/1b8fc962-7036-4d7f-885e-40b631cbdeaf/map to /data1/av2-goro/MIA/1b8fc962-7036-4d7f-885e-40b631cbdeaf/map...
# path /data1/av2-goro/MIA/1b8fc962-7036-4d7f-885e-40b631cbdeaf/map already existed.
# Copying /data1/av2/train/8a0ff1a2-9045-3be3-b67f-3914d88178ec/map to /data1/av2-goro/WDC/8a0ff1a2-9045-3be3-b67f-3914d88178ec/map...
# path /data1/av2-goro/WDC/8a0ff1a2-9045-3be3-b67f-3914d88178ec/map already existed.
# Copying /data1/av2/train/dc4d148d-f84c-307c-b2b7-f0cd7c267f57/map to /data1/av2-goro/PIT/dc4d148d-f84c-307c-b2b7-f0cd7c267f57/map...
# path /data1/av2-goro/PIT/dc4d148d-f84c-307c-b2b7-f0cd7c267f57/map already existed.
# Copying /data1/av2/train/a7c9bb12-322e-3f8e-8798-cf57a4a72f99/map to /data1/av2-goro/MIA/a7c9bb12-322e-3f8e-8798-cf57a4a72f99/map...
# path /data1/av2-goro/MIA/a7c9bb12-322e-3f8e-8798-cf57a4a72f99/map already existed.
# Copying /data1/av2/train/c858bd6a-81ab-3f54-b46d-ffc091ef6945/map to /data1/av2-goro/WDC/c858bd6a-81ab-3f54-b46d-ffc091ef6945/map...
# path /data1/av2-goro/WDC/c858bd6a-81ab-3f54-b46d-ffc091ef6945/map already existed.
# Copying /data1/av2/train/b4d5e738-b937-33fd-8131-bf1df36f598a/map to /data1/av2-goro/MIA/b4d5e738-b937-33fd-8131-bf1df36f598a/map...
# path /data1/av2-goro/MIA/b4d5e738-b937-33fd-8131-bf1df36f598a/map already existed.
# Copying /data1/av2/train/ca4144fb-10e5-3895-836f-87001f59ac65/map to /data1/av2-goro/PIT/ca4144fb-10e5-3895-836f-87001f59ac65/map...
# path /data1/av2-goro/PIT/ca4144fb-10e5-3895-836f-87001f59ac65/map already existed.
# Copying /data1/av2/train/eb142141-683a-3a6d-a207-0302b1ff260d/map to /data1/av2-goro/WDC/eb142141-683a-3a6d-a207-0302b1ff260d/map...
# path /data1/av2-goro/WDC/eb142141-683a-3a6d-a207-0302b1ff260d/map already existed.
# Copying /data1/av2/train/45433055-2b69-3cff-8135-67b3bfa04034/map to /data1/av2-goro/MIA/45433055-2b69-3cff-8135-67b3bfa04034/map...
# path /data1/av2-goro/MIA/45433055-2b69-3cff-8135-67b3bfa04034/map already existed.
# Copying /data1/av2/train/c062ba0f-7591-3225-a57d-8181622dc2da/map to /data1/av2-goro/MIA/c062ba0f-7591-3225-a57d-8181622dc2da/map...
# path /data1/av2-goro/MIA/c062ba0f-7591-3225-a57d-8181622dc2da/map already existed.
# Copying /data1/av2/train/4bab74cd-aba9-4752-9e1f-006cc639d63e/map to /data1/av2-goro/MIA/4bab74cd-aba9-4752-9e1f-006cc639d63e/map...
# path /data1/av2-goro/MIA/4bab74cd-aba9-4752-9e1f-006cc639d63e/map already existed.
# Copying /data1/av2/train/7186d7d2-453e-4193-b327-72b66bbe3fd0/map to /data1/av2-goro/MIA/7186d7d2-453e-4193-b327-72b66bbe3fd0/map...
# path /data1/av2-goro/MIA/7186d7d2-453e-4193-b327-72b66bbe3fd0/map already existed.
# Copying /data1/av2/train/a8a2fbc2-8e77-35a0-9208-f882c3cb2a5c/map to /data1/av2-goro/PIT/a8a2fbc2-8e77-35a0-9208-f882c3cb2a5c/map...
# path /data1/av2-goro/PIT/a8a2fbc2-8e77-35a0-9208-f882c3cb2a5c/map already existed.
# Copying /data1/av2/train/f64ed43e-417a-31ad-a322-b6108bf99a71/map to /data1/av2-goro/PIT/f64ed43e-417a-31ad-a322-b6108bf99a71/map...
# path /data1/av2-goro/PIT/f64ed43e-417a-31ad-a322-b6108bf99a71/map already existed.
# Copying /data1/av2/train/1844c439-b94c-332a-bb94-600818350eb4/map to /data1/av2-goro/MIA/1844c439-b94c-332a-bb94-600818350eb4/map...
# path /data1/av2-goro/MIA/1844c439-b94c-332a-bb94-600818350eb4/map already existed.
# Copying /data1/av2/train/78cbd619-8ded-35b8-87a1-38c4f4aeb82d/map to /data1/av2-goro/MIA/78cbd619-8ded-35b8-87a1-38c4f4aeb82d/map...
# path /data1/av2-goro/MIA/78cbd619-8ded-35b8-87a1-38c4f4aeb82d/map already existed.
# Copying /data1/av2/train/b436606f-daa4-337f-8103-4360bf4704d9/map to /data1/av2-goro/WDC/b436606f-daa4-337f-8103-4360bf4704d9/map...
# path /data1/av2-goro/WDC/b436606f-daa4-337f-8103-4360bf4704d9/map already existed.
# Copying /data1/av2/train/8606d399-57d4-3ae9-938b-db7b8fb7ef8c/map to /data1/av2-goro/PIT/8606d399-57d4-3ae9-938b-db7b8fb7ef8c/map...
# path /data1/av2-goro/PIT/8606d399-57d4-3ae9-938b-db7b8fb7ef8c/map already existed.
# Copying /data1/av2/train/e574050e-f787-3186-9686-2e9aca8102a0/map to /data1/av2-goro/PIT/e574050e-f787-3186-9686-2e9aca8102a0/map...
# path /data1/av2-goro/PIT/e574050e-f787-3186-9686-2e9aca8102a0/map already existed.
# Copying /data1/av2/train/0b1b993a-68b3-3232-9afa-fc9942b5b79b/map to /data1/av2-goro/MIA/0b1b993a-68b3-3232-9afa-fc9942b5b79b/map...
# path /data1/av2-goro/MIA/0b1b993a-68b3-3232-9afa-fc9942b5b79b/map already existed.
# Copying /data1/av2/train/b56e3f47-72a6-34e8-9ada-b4169e28e5b9/map to /data1/av2-goro/PIT/b56e3f47-72a6-34e8-9ada-b4169e28e5b9/map...
# path /data1/av2-goro/PIT/b56e3f47-72a6-34e8-9ada-b4169e28e5b9/map already existed.
# Copying /data1/av2/train/2aea7bd1-432a-43c5-9445-651102487f65/map to /data1/av2-goro/DTW/2aea7bd1-432a-43c5-9445-651102487f65/map...
# path /data1/av2-goro/DTW/2aea7bd1-432a-43c5-9445-651102487f65/map already existed.
# Copying /data1/av2/train/0fc6aa34-323a-33bb-9804-2004599bcd06/map to /data1/av2-goro/PIT/0fc6aa34-323a-33bb-9804-2004599bcd06/map...
# path /data1/av2-goro/PIT/0fc6aa34-323a-33bb-9804-2004599bcd06/map already existed.
# Copying /data1/av2/train/3fbdfb6c-927f-4aaa-81b1-21b02efd4c01/map to /data1/av2-goro/MIA/3fbdfb6c-927f-4aaa-81b1-21b02efd4c01/map...
# path /data1/av2-goro/MIA/3fbdfb6c-927f-4aaa-81b1-21b02efd4c01/map already existed.
# Copying /data1/av2/train/98fd128c-4f32-40fc-a23c-7feb50c4478a/map to /data1/av2-goro/MIA/98fd128c-4f32-40fc-a23c-7feb50c4478a/map...
# path /data1/av2-goro/MIA/98fd128c-4f32-40fc-a23c-7feb50c4478a/map already existed.
# Copying /data1/av2/train/2583a8ee-867d-3db6-b039-35b913fb8f70/map to /data1/av2-goro/PIT/2583a8ee-867d-3db6-b039-35b913fb8f70/map...
# path /data1/av2-goro/PIT/2583a8ee-867d-3db6-b039-35b913fb8f70/map already existed.
# Copying /data1/av2/train/a7bcdabb-f9b7-3c16-806d-3ddf1c2d49a2/map to /data1/av2-goro/MIA/a7bcdabb-f9b7-3c16-806d-3ddf1c2d49a2/map...
# path /data1/av2-goro/MIA/a7bcdabb-f9b7-3c16-806d-3ddf1c2d49a2/map already existed.
# Copying /data1/av2/train/b6c04ab6-1c07-3e17-97d5-e870db090e52/map to /data1/av2-goro/MIA/b6c04ab6-1c07-3e17-97d5-e870db090e52/map...
# path /data1/av2-goro/MIA/b6c04ab6-1c07-3e17-97d5-e870db090e52/map already existed.
# Copying /data1/av2/train/41d69427-364c-366e-94a5-8e556bcac39f/map to /data1/av2-goro/WDC/41d69427-364c-366e-94a5-8e556bcac39f/map...
# path /data1/av2-goro/WDC/41d69427-364c-366e-94a5-8e556bcac39f/map already existed.
# Copying /data1/av2/train/4e302e79-1cb9-358f-a3fb-e133a655af4f/map to /data1/av2-goro/MIA/4e302e79-1cb9-358f-a3fb-e133a655af4f/map...
# path /data1/av2-goro/MIA/4e302e79-1cb9-358f-a3fb-e133a655af4f/map already existed.
# Copying /data1/av2/train/133e2e0b-b0fe-3bb0-b1f9-c846fcfd29e8/map to /data1/av2-goro/PIT/133e2e0b-b0fe-3bb0-b1f9-c846fcfd29e8/map...
# path /data1/av2-goro/PIT/133e2e0b-b0fe-3bb0-b1f9-c846fcfd29e8/map already existed.
# Copying /data1/av2/train/8e5442cf-8882-3b94-bc47-18fcad84bb20/map to /data1/av2-goro/WDC/8e5442cf-8882-3b94-bc47-18fcad84bb20/map...
# path /data1/av2-goro/WDC/8e5442cf-8882-3b94-bc47-18fcad84bb20/map already existed.
# Copying /data1/av2/train/490f13c4-4c1f-3e3b-8a9f-0f27c6906b4e/map to /data1/av2-goro/PIT/490f13c4-4c1f-3e3b-8a9f-0f27c6906b4e/map...
# path /data1/av2-goro/PIT/490f13c4-4c1f-3e3b-8a9f-0f27c6906b4e/map already existed.
# Copying /data1/av2/train/e033cc8e-b23d-3fc6-8954-d90c5e98550e/map to /data1/av2-goro/MIA/e033cc8e-b23d-3fc6-8954-d90c5e98550e/map...
# path /data1/av2-goro/MIA/e033cc8e-b23d-3fc6-8954-d90c5e98550e/map already existed.
# Copying /data1/av2/train/c67f439a-f945-33cb-8517-40c9fdf60d59/map to /data1/av2-goro/PIT/c67f439a-f945-33cb-8517-40c9fdf60d59/map...
# path /data1/av2-goro/PIT/c67f439a-f945-33cb-8517-40c9fdf60d59/map already existed.
# Copying /data1/av2/train/7c5e3704-33c8-3a4e-b032-9187a6f90206/map to /data1/av2-goro/PIT/7c5e3704-33c8-3a4e-b032-9187a6f90206/map...
# path /data1/av2-goro/PIT/7c5e3704-33c8-3a4e-b032-9187a6f90206/map already existed.
# Copying /data1/av2/train/8c019de9-7043-37bc-9498-b5858e7240af/map to /data1/av2-goro/DTW/8c019de9-7043-37bc-9498-b5858e7240af/map...
# path /data1/av2-goro/DTW/8c019de9-7043-37bc-9498-b5858e7240af/map already existed.
# Copying /data1/av2/train/47972731-b0ea-3c38-a10f-5ffdd42329fc/map to /data1/av2-goro/WDC/47972731-b0ea-3c38-a10f-5ffdd42329fc/map...
# path /data1/av2-goro/WDC/47972731-b0ea-3c38-a10f-5ffdd42329fc/map already existed.
# Copying /data1/av2/train/790d3c83-f6bf-348e-80e7-12f29240e598/map to /data1/av2-goro/PIT/790d3c83-f6bf-348e-80e7-12f29240e598/map...
# path /data1/av2-goro/PIT/790d3c83-f6bf-348e-80e7-12f29240e598/map already existed.
# Copying /data1/av2/train/ccb4e29d-e88f-3fbe-8958-67cfd62350a3/map to /data1/av2-goro/DTW/ccb4e29d-e88f-3fbe-8958-67cfd62350a3/map...
# path /data1/av2-goro/DTW/ccb4e29d-e88f-3fbe-8958-67cfd62350a3/map already existed.
# Copying /data1/av2/train/c69e348a-8e10-31dc-b71b-dd8e5cfd7211/map to /data1/av2-goro/MIA/c69e348a-8e10-31dc-b71b-dd8e5cfd7211/map...
# path /data1/av2-goro/MIA/c69e348a-8e10-31dc-b71b-dd8e5cfd7211/map already existed.
# Copying /data1/av2/train/eed8593d-60e3-3e41-9fea-55f544b01749/map to /data1/av2-goro/MIA/eed8593d-60e3-3e41-9fea-55f544b01749/map...
# path /data1/av2-goro/MIA/eed8593d-60e3-3e41-9fea-55f544b01749/map already existed.
# Copying /data1/av2/train/e757cddd-5ff5-305a-af11-d7c6747d3979/map to /data1/av2-goro/PIT/e757cddd-5ff5-305a-af11-d7c6747d3979/map...
# path /data1/av2-goro/PIT/e757cddd-5ff5-305a-af11-d7c6747d3979/map already existed.
# Copying /data1/av2/train/95a47a36-1041-3924-bbd0-4dcad52c323a/map to /data1/av2-goro/MIA/95a47a36-1041-3924-bbd0-4dcad52c323a/map...
# path /data1/av2-goro/MIA/95a47a36-1041-3924-bbd0-4dcad52c323a/map already existed.
# Copying /data1/av2/train/a3f59292-ad1d-370a-afde-64a9e16b341c/map to /data1/av2-goro/DTW/a3f59292-ad1d-370a-afde-64a9e16b341c/map...
# path /data1/av2-goro/DTW/a3f59292-ad1d-370a-afde-64a9e16b341c/map already existed.
# Copying /data1/av2/train/c556f8e0-a001-3586-b2cf-d3256685c39f/map to /data1/av2-goro/MIA/c556f8e0-a001-3586-b2cf-d3256685c39f/map...
# path /data1/av2-goro/MIA/c556f8e0-a001-3586-b2cf-d3256685c39f/map already existed.
# Copying /data1/av2/train/87ce1d90-ca77-363b-a885-ec0ef6783847/map to /data1/av2-goro/MIA/87ce1d90-ca77-363b-a885-ec0ef6783847/map...
# path /data1/av2-goro/MIA/87ce1d90-ca77-363b-a885-ec0ef6783847/map already existed.
# Copying /data1/av2/train/1bf2bf1c-64d1-308f-afd1-220de9d30290/map to /data1/av2-goro/PIT/1bf2bf1c-64d1-308f-afd1-220de9d30290/map...
# path /data1/av2-goro/PIT/1bf2bf1c-64d1-308f-afd1-220de9d30290/map already existed.
# Copying /data1/av2/train/57636c80-9335-3aae-af70-11755db93854/map to /data1/av2-goro/MIA/57636c80-9335-3aae-af70-11755db93854/map...
# path /data1/av2-goro/MIA/57636c80-9335-3aae-af70-11755db93854/map already existed.
# Copying /data1/av2/train/648e8393-f46f-384b-9bd1-c25a2285077d/map to /data1/av2-goro/MIA/648e8393-f46f-384b-9bd1-c25a2285077d/map...
# path /data1/av2-goro/MIA/648e8393-f46f-384b-9bd1-c25a2285077d/map already existed.
# Copying /data1/av2/train/bba89165-0e5d-3052-abb6-6a61e37861a3/map to /data1/av2-goro/MIA/bba89165-0e5d-3052-abb6-6a61e37861a3/map...
# path /data1/av2-goro/MIA/bba89165-0e5d-3052-abb6-6a61e37861a3/map already existed.
# Copying /data1/av2/train/5481321f-d317-3e80-8061-6e9c635c4ca9/map to /data1/av2-goro/PIT/5481321f-d317-3e80-8061-6e9c635c4ca9/map...
# path /data1/av2-goro/PIT/5481321f-d317-3e80-8061-6e9c635c4ca9/map already existed.
# Copying /data1/av2/train/d551b8f9-feab-3946-9524-219e07988341/map to /data1/av2-goro/PIT/d551b8f9-feab-3946-9524-219e07988341/map...
# path /data1/av2-goro/PIT/d551b8f9-feab-3946-9524-219e07988341/map already existed.
# Copying /data1/av2/train/d6ba4898-1369-3521-981c-b9ac57420418/map to /data1/av2-goro/MIA/d6ba4898-1369-3521-981c-b9ac57420418/map...
# path /data1/av2-goro/MIA/d6ba4898-1369-3521-981c-b9ac57420418/map already existed.
# Copying /data1/av2/train/823371b1-3197-35d6-a6b7-bfd432e10440/map to /data1/av2-goro/MIA/823371b1-3197-35d6-a6b7-bfd432e10440/map...
# path /data1/av2-goro/MIA/823371b1-3197-35d6-a6b7-bfd432e10440/map already existed.
# Copying /data1/av2/train/2501c6d0-071c-3a7a-b51f-c8cbd37abe25/map to /data1/av2-goro/MIA/2501c6d0-071c-3a7a-b51f-c8cbd37abe25/map...
# path /data1/av2-goro/MIA/2501c6d0-071c-3a7a-b51f-c8cbd37abe25/map already existed.
# Copying /data1/av2/train/828ddef2-7609-3683-8e32-c21e7c07d6a6/map to /data1/av2-goro/MIA/828ddef2-7609-3683-8e32-c21e7c07d6a6/map...
# path /data1/av2-goro/MIA/828ddef2-7609-3683-8e32-c21e7c07d6a6/map already existed.
# Copying /data1/av2/train/6ee06433-4820-3211-999a-95b79b2c692e/map to /data1/av2-goro/WDC/6ee06433-4820-3211-999a-95b79b2c692e/map...
# path /data1/av2-goro/WDC/6ee06433-4820-3211-999a-95b79b2c692e/map already existed.
# Copying /data1/av2/train/ff6adc87-5f47-32f7-b36a-546453c0e332/map to /data1/av2-goro/MIA/ff6adc87-5f47-32f7-b36a-546453c0e332/map...
# path /data1/av2-goro/MIA/ff6adc87-5f47-32f7-b36a-546453c0e332/map already existed.
# Copying /data1/av2/train/71d1938d-536e-39eb-beb4-bb4f5b607427/map to /data1/av2-goro/DTW/71d1938d-536e-39eb-beb4-bb4f5b607427/map...
# path /data1/av2-goro/DTW/71d1938d-536e-39eb-beb4-bb4f5b607427/map already existed.
# Copying /data1/av2/train/fac8a63c-6b75-39d0-9f57-4344fde0f794/map to /data1/av2-goro/WDC/fac8a63c-6b75-39d0-9f57-4344fde0f794/map...
# path /data1/av2-goro/WDC/fac8a63c-6b75-39d0-9f57-4344fde0f794/map already existed.
# Copying /data1/av2/train/991d11df-0265-3e41-b942-5b0c615d21e2/map to /data1/av2-goro/WDC/991d11df-0265-3e41-b942-5b0c615d21e2/map...
# path /data1/av2-goro/WDC/991d11df-0265-3e41-b942-5b0c615d21e2/map already existed.
# Copying /data1/av2/train/1c8f1189-c4fe-3303-bf2a-f88f5751b81e/map to /data1/av2-goro/MIA/1c8f1189-c4fe-3303-bf2a-f88f5751b81e/map...
# path /data1/av2-goro/MIA/1c8f1189-c4fe-3303-bf2a-f88f5751b81e/map already existed.
# Copying /data1/av2/train/64b24fd1-f639-4f7e-a535-dbfe9fd737a1/map to /data1/av2-goro/MIA/64b24fd1-f639-4f7e-a535-dbfe9fd737a1/map...
# path /data1/av2-goro/MIA/64b24fd1-f639-4f7e-a535-dbfe9fd737a1/map already existed.
# Copying /data1/av2/train/fb0c5970-dbf7-4c77-b3b6-2c8cc41b9d6f/map to /data1/av2-goro/DTW/fb0c5970-dbf7-4c77-b3b6-2c8cc41b9d6f/map...
# path /data1/av2-goro/DTW/fb0c5970-dbf7-4c77-b3b6-2c8cc41b9d6f/map already existed.
# Copying /data1/av2/train/f46707f9-435f-3a06-9017-deae11feab53/map to /data1/av2-goro/MIA/f46707f9-435f-3a06-9017-deae11feab53/map...
# path /data1/av2-goro/MIA/f46707f9-435f-3a06-9017-deae11feab53/map already existed.
# Copying /data1/av2/train/65d3f43d-1969-35d4-bf86-bd5e4b1ac803/map to /data1/av2-goro/PIT/65d3f43d-1969-35d4-bf86-bd5e4b1ac803/map...
# path /data1/av2-goro/PIT/65d3f43d-1969-35d4-bf86-bd5e4b1ac803/map already existed.
# Copying /data1/av2/train/c70b2c64-7a9a-37c5-b974-709fa0536675/map to /data1/av2-goro/PIT/c70b2c64-7a9a-37c5-b974-709fa0536675/map...
# path /data1/av2-goro/PIT/c70b2c64-7a9a-37c5-b974-709fa0536675/map already existed.
# Copying /data1/av2/train/93b755f1-f865-44dc-a98d-cae5eb1a25d0/map to /data1/av2-goro/MIA/93b755f1-f865-44dc-a98d-cae5eb1a25d0/map...
# path /data1/av2-goro/MIA/93b755f1-f865-44dc-a98d-cae5eb1a25d0/map already existed.
# Copying /data1/av2/train/6cc0bb26-5afb-3688-b237-b9c64c2800e5/map to /data1/av2-goro/DTW/6cc0bb26-5afb-3688-b237-b9c64c2800e5/map...
# path /data1/av2-goro/DTW/6cc0bb26-5afb-3688-b237-b9c64c2800e5/map already existed.
# Copying /data1/av2/train/fb2cce69-655d-3203-990a-74301895408d/map to /data1/av2-goro/MIA/fb2cce69-655d-3203-990a-74301895408d/map...
# path /data1/av2-goro/MIA/fb2cce69-655d-3203-990a-74301895408d/map already existed.
# Copying /data1/av2/train/49d76058-b4f0-3931-86fa-de160b4c1b88/map to /data1/av2-goro/PIT/49d76058-b4f0-3931-86fa-de160b4c1b88/map...
# path /data1/av2-goro/PIT/49d76058-b4f0-3931-86fa-de160b4c1b88/map already existed.
# Copying /data1/av2/train/8aeeeeca-6a79-34ef-b667-835d53536a8f/map to /data1/av2-goro/MIA/8aeeeeca-6a79-34ef-b667-835d53536a8f/map...
# path /data1/av2-goro/MIA/8aeeeeca-6a79-34ef-b667-835d53536a8f/map already existed.
# Copying /data1/av2/train/ac1b1697-42b9-4225-a666-d17f72204fa8/map to /data1/av2-goro/MIA/ac1b1697-42b9-4225-a666-d17f72204fa8/map...
# path /data1/av2-goro/MIA/ac1b1697-42b9-4225-a666-d17f72204fa8/map already existed.
# Copying /data1/av2/train/e4d53680-f7ef-364b-91a4-00e5aa91ab9b/map to /data1/av2-goro/WDC/e4d53680-f7ef-364b-91a4-00e5aa91ab9b/map...
# path /data1/av2-goro/WDC/e4d53680-f7ef-364b-91a4-00e5aa91ab9b/map already existed.
# Copying /data1/av2/train/e3a935bf-1428-32a4-8d53-caa71ee3de8f/map to /data1/av2-goro/MIA/e3a935bf-1428-32a4-8d53-caa71ee3de8f/map...
# path /data1/av2-goro/MIA/e3a935bf-1428-32a4-8d53-caa71ee3de8f/map already existed.
# Copying /data1/av2/train/ede387f4-f390-3f0e-a071-eb543b73ed73/map to /data1/av2-goro/MIA/ede387f4-f390-3f0e-a071-eb543b73ed73/map...
# path /data1/av2-goro/MIA/ede387f4-f390-3f0e-a071-eb543b73ed73/map already existed.
# Copying /data1/av2/train/a146ab19-f4f3-334f-b830-fc68de83e26c/map to /data1/av2-goro/PIT/a146ab19-f4f3-334f-b830-fc68de83e26c/map...
# path /data1/av2-goro/PIT/a146ab19-f4f3-334f-b830-fc68de83e26c/map already existed.
# Copying /data1/av2/train/a1c1d559-0480-39d2-94f0-1a89f0226c4f/map to /data1/av2-goro/WDC/a1c1d559-0480-39d2-94f0-1a89f0226c4f/map...
# path /data1/av2-goro/WDC/a1c1d559-0480-39d2-94f0-1a89f0226c4f/map already existed.
# Copying /data1/av2/train/35f32393-e82f-3b20-b214-1f6a43d60f23/map to /data1/av2-goro/MIA/35f32393-e82f-3b20-b214-1f6a43d60f23/map...
# path /data1/av2-goro/MIA/35f32393-e82f-3b20-b214-1f6a43d60f23/map already existed.
# Copying /data1/av2/train/0a8a4cfa-4902-3a76-8301-08698d6290a2/map to /data1/av2-goro/PIT/0a8a4cfa-4902-3a76-8301-08698d6290a2/map...
# path /data1/av2-goro/PIT/0a8a4cfa-4902-3a76-8301-08698d6290a2/map already existed.
# Copying /data1/av2/train/c730e199-fb8d-3abf-b7aa-bbc81bf8c08f/map to /data1/av2-goro/PIT/c730e199-fb8d-3abf-b7aa-bbc81bf8c08f/map...
# path /data1/av2-goro/PIT/c730e199-fb8d-3abf-b7aa-bbc81bf8c08f/map already existed.
# Copying /data1/av2/train/380e5bf0-1c68-36a4-ac64-09a03b60bebf/map to /data1/av2-goro/PIT/380e5bf0-1c68-36a4-ac64-09a03b60bebf/map...
# path /data1/av2-goro/PIT/380e5bf0-1c68-36a4-ac64-09a03b60bebf/map already existed.
# Copying /data1/av2/train/b81922e7-092f-3052-8cd1-fec6a6763295/map to /data1/av2-goro/WDC/b81922e7-092f-3052-8cd1-fec6a6763295/map...
# path /data1/av2-goro/WDC/b81922e7-092f-3052-8cd1-fec6a6763295/map already existed.
# Copying /data1/av2/train/8ee606e6-4cbd-3c07-8419-fbda836ccaac/map to /data1/av2-goro/WDC/8ee606e6-4cbd-3c07-8419-fbda836ccaac/map...
# path /data1/av2-goro/WDC/8ee606e6-4cbd-3c07-8419-fbda836ccaac/map already existed.
# Copying /data1/av2/train/806d3ab3-4c53-30d6-ba6a-09ef6df5af5a/map to /data1/av2-goro/DTW/806d3ab3-4c53-30d6-ba6a-09ef6df5af5a/map...
# path /data1/av2-goro/DTW/806d3ab3-4c53-30d6-ba6a-09ef6df5af5a/map already existed.
# Copying /data1/av2/train/ce0e814a-d9df-3975-a521-d8ae9a091e96/map to /data1/av2-goro/MIA/ce0e814a-d9df-3975-a521-d8ae9a091e96/map...
# path /data1/av2-goro/MIA/ce0e814a-d9df-3975-a521-d8ae9a091e96/map already existed.
# Copying /data1/av2/train/6aae7f38-21de-31bf-8761-29d458338958/map to /data1/av2-goro/DTW/6aae7f38-21de-31bf-8761-29d458338958/map...
# path /data1/av2-goro/DTW/6aae7f38-21de-31bf-8761-29d458338958/map already existed.
# Copying /data1/av2/train/40bfcbec-ec59-3731-8e75-67f0bddc3b01/map to /data1/av2-goro/ATX/40bfcbec-ec59-3731-8e75-67f0bddc3b01/map...
# path /data1/av2-goro/ATX/40bfcbec-ec59-3731-8e75-67f0bddc3b01/map already existed.
# Copying /data1/av2/train/9fd55542-e982-361f-814f-61ad4ad07adf/map to /data1/av2-goro/PIT/9fd55542-e982-361f-814f-61ad4ad07adf/map...
# path /data1/av2-goro/PIT/9fd55542-e982-361f-814f-61ad4ad07adf/map already existed.
# Copying /data1/av2/train/e88132d0-4512-3d6f-a1c8-f60972332af5/map to /data1/av2-goro/MIA/e88132d0-4512-3d6f-a1c8-f60972332af5/map...
# path /data1/av2-goro/MIA/e88132d0-4512-3d6f-a1c8-f60972332af5/map already existed.
# Copying /data1/av2/train/8934694e-8085-3673-96dd-eacebe691ed1/map to /data1/av2-goro/PIT/8934694e-8085-3673-96dd-eacebe691ed1/map...
# path /data1/av2-goro/PIT/8934694e-8085-3673-96dd-eacebe691ed1/map already existed.
# Copying /data1/av2/train/d9c267be-f19a-3183-afe0-f0625a375743/map to /data1/av2-goro/MIA/d9c267be-f19a-3183-afe0-f0625a375743/map...
# path /data1/av2-goro/MIA/d9c267be-f19a-3183-afe0-f0625a375743/map already existed.
# Copying /data1/av2/train/c2ec8955-1797-338f-9486-d7c41926f791/map to /data1/av2-goro/MIA/c2ec8955-1797-338f-9486-d7c41926f791/map...
# path /data1/av2-goro/MIA/c2ec8955-1797-338f-9486-d7c41926f791/map already existed.
# Copying /data1/av2/train/1579b300-e7f5-3318-97c2-2c827b0c411e/map to /data1/av2-goro/DTW/1579b300-e7f5-3318-97c2-2c827b0c411e/map...
# path /data1/av2-goro/DTW/1579b300-e7f5-3318-97c2-2c827b0c411e/map already existed.
# Copying /data1/av2/train/74a3e9ae-6811-4d11-a112-4c4963773cfe/map to /data1/av2-goro/PIT/74a3e9ae-6811-4d11-a112-4c4963773cfe/map...
# path /data1/av2-goro/PIT/74a3e9ae-6811-4d11-a112-4c4963773cfe/map already existed.
# Copying /data1/av2/train/2716d83e-8c4f-39a3-a2a3-d5e255fe8a03/map to /data1/av2-goro/WDC/2716d83e-8c4f-39a3-a2a3-d5e255fe8a03/map...
# path /data1/av2-goro/WDC/2716d83e-8c4f-39a3-a2a3-d5e255fe8a03/map already existed.
# Copying /data1/av2/train/a4f240a0-12d4-3542-a11f-0c592e90e4da/map to /data1/av2-goro/MIA/a4f240a0-12d4-3542-a11f-0c592e90e4da/map...
# path /data1/av2-goro/MIA/a4f240a0-12d4-3542-a11f-0c592e90e4da/map already existed.
# Copying /data1/av2/train/633addf9-441c-35e7-868a-738aa612d51c/map to /data1/av2-goro/MIA/633addf9-441c-35e7-868a-738aa612d51c/map...
# path /data1/av2-goro/MIA/633addf9-441c-35e7-868a-738aa612d51c/map already existed.
# Copying /data1/av2/train/575d8d24-ba88-3b18-84c0-df5b29dccfde/map to /data1/av2-goro/ATX/575d8d24-ba88-3b18-84c0-df5b29dccfde/map...
# path /data1/av2-goro/ATX/575d8d24-ba88-3b18-84c0-df5b29dccfde/map already existed.
# Copying /data1/av2/train/7ebbdbeb-a8de-3612-8f22-6ce91980841d/map to /data1/av2-goro/MIA/7ebbdbeb-a8de-3612-8f22-6ce91980841d/map...
# path /data1/av2-goro/MIA/7ebbdbeb-a8de-3612-8f22-6ce91980841d/map already existed.
# Copying /data1/av2/train/cd2353c2-0fb6-3e18-8281-4c0df1d3189a/map to /data1/av2-goro/WDC/cd2353c2-0fb6-3e18-8281-4c0df1d3189a/map...
# path /data1/av2-goro/WDC/cd2353c2-0fb6-3e18-8281-4c0df1d3189a/map already existed.
# Copying /data1/av2/train/6419dcfd-8777-35fa-924c-ebefccde0a9b/map to /data1/av2-goro/PIT/6419dcfd-8777-35fa-924c-ebefccde0a9b/map...
# path /data1/av2-goro/PIT/6419dcfd-8777-35fa-924c-ebefccde0a9b/map already existed.
# Copying /data1/av2/train/2772dd5f-bc0a-47ea-ae19-a5e0dbef8f41/map to /data1/av2-goro/PIT/2772dd5f-bc0a-47ea-ae19-a5e0dbef8f41/map...
# path /data1/av2-goro/PIT/2772dd5f-bc0a-47ea-ae19-a5e0dbef8f41/map already existed.
# Copying /data1/av2/train/9a8aea4b-9b61-3884-9f3c-84c3c36e6373/map to /data1/av2-goro/PIT/9a8aea4b-9b61-3884-9f3c-84c3c36e6373/map...
# path /data1/av2-goro/PIT/9a8aea4b-9b61-3884-9f3c-84c3c36e6373/map already existed.
# Copying /data1/av2/train/61e56102-4d85-3a40-bbba-1a007c816f68/map to /data1/av2-goro/PIT/61e56102-4d85-3a40-bbba-1a007c816f68/map...
# path /data1/av2-goro/PIT/61e56102-4d85-3a40-bbba-1a007c816f68/map already existed.
# Copying /data1/av2/train/c2f301b6-5d19-3296-a8ac-418ff48e052b/map to /data1/av2-goro/WDC/c2f301b6-5d19-3296-a8ac-418ff48e052b/map...
# path /data1/av2-goro/WDC/c2f301b6-5d19-3296-a8ac-418ff48e052b/map already existed.
# Copying /data1/av2/train/f9f6a7e9-4f79-3fdf-b1a7-ba300622f116/map to /data1/av2-goro/MIA/f9f6a7e9-4f79-3fdf-b1a7-ba300622f116/map...
# path /data1/av2-goro/MIA/f9f6a7e9-4f79-3fdf-b1a7-ba300622f116/map already existed.
# Copying /data1/av2/train/22dcf96c-ef5e-376b-9db5-dc9f91040f5e/map to /data1/av2-goro/ATX/22dcf96c-ef5e-376b-9db5-dc9f91040f5e/map...
# path /data1/av2-goro/ATX/22dcf96c-ef5e-376b-9db5-dc9f91040f5e/map already existed.
# Copying /data1/av2/train/35a15c5c-fa4a-3838-a724-396e112ec95c/map to /data1/av2-goro/PIT/35a15c5c-fa4a-3838-a724-396e112ec95c/map...
# path /data1/av2-goro/PIT/35a15c5c-fa4a-3838-a724-396e112ec95c/map already existed.
# Copying /data1/av2/train/dd251cc5-736d-3b76-8ad3-3f6cb138178e/map to /data1/av2-goro/WDC/dd251cc5-736d-3b76-8ad3-3f6cb138178e/map...
# path /data1/av2-goro/WDC/dd251cc5-736d-3b76-8ad3-3f6cb138178e/map already existed.
# Copying /data1/av2/train/b0663029-8f8d-398a-8a28-81ba29224696/map to /data1/av2-goro/MIA/b0663029-8f8d-398a-8a28-81ba29224696/map...
# path /data1/av2-goro/MIA/b0663029-8f8d-398a-8a28-81ba29224696/map already existed.
# Copying /data1/av2/train/ad870270-f3d8-3790-866a-78d61b5b76ee/map to /data1/av2-goro/MIA/ad870270-f3d8-3790-866a-78d61b5b76ee/map...
# path /data1/av2-goro/MIA/ad870270-f3d8-3790-866a-78d61b5b76ee/map already existed.
# Copying /data1/av2/train/b8d83d8e-1574-3efd-b067-a3ed422a259e/map to /data1/av2-goro/DTW/b8d83d8e-1574-3efd-b067-a3ed422a259e/map...
# path /data1/av2-goro/DTW/b8d83d8e-1574-3efd-b067-a3ed422a259e/map already existed.
# Copying /data1/av2/train/73539e96-eef2-3302-bdf4-a39e9d95b6e7/map to /data1/av2-goro/MIA/73539e96-eef2-3302-bdf4-a39e9d95b6e7/map...
# path /data1/av2-goro/MIA/73539e96-eef2-3302-bdf4-a39e9d95b6e7/map already existed.
# Copying /data1/av2/train/c96a09c8-46ed-391f-8a66-c46fa8b76029/map to /data1/av2-goro/PIT/c96a09c8-46ed-391f-8a66-c46fa8b76029/map...
# path /data1/av2-goro/PIT/c96a09c8-46ed-391f-8a66-c46fa8b76029/map already existed.
# Copying /data1/av2/train/0526e68e-2ff1-3e53-b0f8-45df02e45a93/map to /data1/av2-goro/PIT/0526e68e-2ff1-3e53-b0f8-45df02e45a93/map...
# path /data1/av2-goro/PIT/0526e68e-2ff1-3e53-b0f8-45df02e45a93/map already existed.
# Copying /data1/av2/train/d97ae2c0-b8d1-341c-94b7-f19d5fd2982a/map to /data1/av2-goro/PIT/d97ae2c0-b8d1-341c-94b7-f19d5fd2982a/map...
# path /data1/av2-goro/PIT/d97ae2c0-b8d1-341c-94b7-f19d5fd2982a/map already existed.
# Copying /data1/av2/train/b5a1b0b0-a7fc-3a47-af82-9b25a81a8c0b/map to /data1/av2-goro/WDC/b5a1b0b0-a7fc-3a47-af82-9b25a81a8c0b/map...
# path /data1/av2-goro/WDC/b5a1b0b0-a7fc-3a47-af82-9b25a81a8c0b/map already existed.
# Copying /data1/av2/train/5f2b8881-3447-3905-99f8-def9d72aae42/map to /data1/av2-goro/MIA/5f2b8881-3447-3905-99f8-def9d72aae42/map...
# path /data1/av2-goro/MIA/5f2b8881-3447-3905-99f8-def9d72aae42/map already existed.
# Copying /data1/av2/train/f7cdc2d1-f59a-30a2-aae8-8bb81c769e6e/map to /data1/av2-goro/MIA/f7cdc2d1-f59a-30a2-aae8-8bb81c769e6e/map...
# path /data1/av2-goro/MIA/f7cdc2d1-f59a-30a2-aae8-8bb81c769e6e/map already existed.
# Copying /data1/av2/train/924116d9-0a48-3d97-b8c9-0d16b087c16a/map to /data1/av2-goro/PIT/924116d9-0a48-3d97-b8c9-0d16b087c16a/map...
# path /data1/av2-goro/PIT/924116d9-0a48-3d97-b8c9-0d16b087c16a/map already existed.
# Copying /data1/av2/train/5d333477-796b-3e49-bf41-0cdbed39c8dd/map to /data1/av2-goro/WDC/5d333477-796b-3e49-bf41-0cdbed39c8dd/map...
# path /data1/av2-goro/WDC/5d333477-796b-3e49-bf41-0cdbed39c8dd/map already existed.
# Copying /data1/av2/train/d0cc23f4-f4ab-3755-8e63-2e3940f68d89/map to /data1/av2-goro/MIA/d0cc23f4-f4ab-3755-8e63-2e3940f68d89/map...
# path /data1/av2-goro/MIA/d0cc23f4-f4ab-3755-8e63-2e3940f68d89/map already existed.
# Copying /data1/av2/train/7ad46cf0-aa12-4050-ac2d-cf34b5f64d41/map to /data1/av2-goro/PIT/7ad46cf0-aa12-4050-ac2d-cf34b5f64d41/map...
# path /data1/av2-goro/PIT/7ad46cf0-aa12-4050-ac2d-cf34b5f64d41/map already existed.
# Copying /data1/av2/train/094c4119-eb33-3dfb-a18d-492cbdc8413a/map to /data1/av2-goro/MIA/094c4119-eb33-3dfb-a18d-492cbdc8413a/map...
# path /data1/av2-goro/MIA/094c4119-eb33-3dfb-a18d-492cbdc8413a/map already existed.
# Copying /data1/av2/train/64037371-4aa4-3fed-97f4-bafc1674caee/map to /data1/av2-goro/MIA/64037371-4aa4-3fed-97f4-bafc1674caee/map...
# path /data1/av2-goro/MIA/64037371-4aa4-3fed-97f4-bafc1674caee/map already existed.
# Copying /data1/av2/train/7c696d35-e34f-38b0-b4b4-e88803ad1f6a/map to /data1/av2-goro/PIT/7c696d35-e34f-38b0-b4b4-e88803ad1f6a/map...
# path /data1/av2-goro/PIT/7c696d35-e34f-38b0-b4b4-e88803ad1f6a/map already existed.
# Copying /data1/av2/train/d72c43a5-95bf-3a3e-9019-cf25cc0a61c0/map to /data1/av2-goro/MIA/d72c43a5-95bf-3a3e-9019-cf25cc0a61c0/map...
# path /data1/av2-goro/MIA/d72c43a5-95bf-3a3e-9019-cf25cc0a61c0/map already existed.
# Copying /data1/av2/train/1e6f21fd-5c8a-3526-ac50-72adae89d6a8/map to /data1/av2-goro/MIA/1e6f21fd-5c8a-3526-ac50-72adae89d6a8/map...
# path /data1/av2-goro/MIA/1e6f21fd-5c8a-3526-ac50-72adae89d6a8/map already existed.
# Copying /data1/av2/train/4207ef92-0b3b-4708-8868-4ffcaef308e0/map to /data1/av2-goro/DTW/4207ef92-0b3b-4708-8868-4ffcaef308e0/map...
# path /data1/av2-goro/DTW/4207ef92-0b3b-4708-8868-4ffcaef308e0/map already existed.
# Copying /data1/av2/train/c71cd96c-8e3f-3861-9ece-fcbabebc63a8/map to /data1/av2-goro/DTW/c71cd96c-8e3f-3861-9ece-fcbabebc63a8/map...
# path /data1/av2-goro/DTW/c71cd96c-8e3f-3861-9ece-fcbabebc63a8/map already existed.
# Copying /data1/av2/train/5d391e54-adec-3584-adf0-5025d7564e1b/map to /data1/av2-goro/MIA/5d391e54-adec-3584-adf0-5025d7564e1b/map...
# path /data1/av2-goro/MIA/5d391e54-adec-3584-adf0-5025d7564e1b/map already existed.
# ...
# Copying /data1/av2/val/02a00399-3857-444e-8db3-a8f58489c394/map to /data1/av2-goro/MIA/02a00399-3857-444e-8db3-a8f58489c394/map...
# path /data1/av2-goro/MIA/02a00399-3857-444e-8db3-a8f58489c394/map already existed.
# Copying /data1/av2/val/b8489c02-60d0-3f44-a3b4-9de62830d666/map to /data1/av2-goro/MIA/b8489c02-60d0-3f44-a3b4-9de62830d666/map...
# path /data1/av2-goro/MIA/b8489c02-60d0-3f44-a3b4-9de62830d666/map already existed.
# Copying /data1/av2/val/bf360aeb-1bbd-3c1e-b143-09cf83e4f2e4/map to /data1/av2-goro/PIT/bf360aeb-1bbd-3c1e-b143-09cf83e4f2e4/map...
# path /data1/av2-goro/PIT/bf360aeb-1bbd-3c1e-b143-09cf83e4f2e4/map already existed.
# Copying /data1/av2/val/88f47a10-87b4-3ea8-a0c7-a07d825b647d/map to /data1/av2-goro/PAO/88f47a10-87b4-3ea8-a0c7-a07d825b647d/map...
# path /data1/av2-goro/PAO/88f47a10-87b4-3ea8-a0c7-a07d825b647d/map already existed.
# Copying /data1/av2/val/fbee355f-8878-31fa-8ac8-b9a45a3f130a/map to /data1/av2-goro/PIT/fbee355f-8878-31fa-8ac8-b9a45a3f130a/map...
# path /data1/av2-goro/PIT/fbee355f-8878-31fa-8ac8-b9a45a3f130a/map already existed.
# Copying /data1/av2/val/bdb9d309-f14b-3ff6-ad1f-5d3f3f95a13e/map to /data1/av2-goro/WDC/bdb9d309-f14b-3ff6-ad1f-5d3f3f95a13e/map...
# path /data1/av2-goro/WDC/bdb9d309-f14b-3ff6-ad1f-5d3f3f95a13e/map already existed.
# Copying /data1/av2/val/cf5aaa11-4f92-3377-a7a2-861f305023eb/map to /data1/av2-goro/DTW/cf5aaa11-4f92-3377-a7a2-861f305023eb/map...
# path /data1/av2-goro/DTW/cf5aaa11-4f92-3377-a7a2-861f305023eb/map already existed.
# Copying /data1/av2/val/f1275002-842e-3571-8f7d-05816bc7cf56/map to /data1/av2-goro/PIT/f1275002-842e-3571-8f7d-05816bc7cf56/map...
# path /data1/av2-goro/PIT/f1275002-842e-3571-8f7d-05816bc7cf56/map already existed.
# Copying /data1/av2/val/9bb1f857-8b61-369f-a537-484c1323ae32/map to /data1/av2-goro/PAO/9bb1f857-8b61-369f-a537-484c1323ae32/map...
# path /data1/av2-goro/PAO/9bb1f857-8b61-369f-a537-484c1323ae32/map already existed.
# Copying /data1/av2/val/a060c4c1-b9fc-39c1-9d30-d93a124c9066/map to /data1/av2-goro/PIT/a060c4c1-b9fc-39c1-9d30-d93a124c9066/map...
# path /data1/av2-goro/PIT/a060c4c1-b9fc-39c1-9d30-d93a124c9066/map already existed.
# Copying /data1/av2/val/e13c06cb-cd01-380e-946f-6d92ac1af49d/map to /data1/av2-goro/WDC/e13c06cb-cd01-380e-946f-6d92ac1af49d/map...
# path /data1/av2-goro/WDC/e13c06cb-cd01-380e-946f-6d92ac1af49d/map already existed.
# Copying /data1/av2/val/d5d6f11c-3026-3e0e-9d67-c111233e22de/map to /data1/av2-goro/PAO/d5d6f11c-3026-3e0e-9d67-c111233e22de/map...
# path /data1/av2-goro/PAO/d5d6f11c-3026-3e0e-9d67-c111233e22de/map already existed.
# Copying /data1/av2/val/858d739b-a0ba-35aa-bafc-4f7988bcad17/map to /data1/av2-goro/PIT/858d739b-a0ba-35aa-bafc-4f7988bcad17/map...
# path /data1/av2-goro/PIT/858d739b-a0ba-35aa-bafc-4f7988bcad17/map already existed.
# Copying /data1/av2/val/2f2321d2-7912-3567-a789-25e46a145bda/map to /data1/av2-goro/MIA/2f2321d2-7912-3567-a789-25e46a145bda/map...
# path /data1/av2-goro/MIA/2f2321d2-7912-3567-a789-25e46a145bda/map already existed.
# Copying /data1/av2/val/95bf6003-7068-3a78-a0c0-9e470a06e60f/map to /data1/av2-goro/PIT/95bf6003-7068-3a78-a0c0-9e470a06e60f/map...
# path /data1/av2-goro/PIT/95bf6003-7068-3a78-a0c0-9e470a06e60f/map already existed.
# Copying /data1/av2/val/f4c94798-4d77-36ab-bdc5-c1194e5e7aff/map to /data1/av2-goro/PIT/f4c94798-4d77-36ab-bdc5-c1194e5e7aff/map...
# path /data1/av2-goro/PIT/f4c94798-4d77-36ab-bdc5-c1194e5e7aff/map already existed.
# Copying /data1/av2/val/29a00842-ead2-3050-b587-c5ef507e4125/map to /data1/av2-goro/PIT/29a00842-ead2-3050-b587-c5ef507e4125/map...
# path /data1/av2-goro/PIT/29a00842-ead2-3050-b587-c5ef507e4125/map already existed.
# Copying /data1/av2/val/544a8102-0ef5-3044-921e-dc0544370376/map to /data1/av2-goro/DTW/544a8102-0ef5-3044-921e-dc0544370376/map...
# path /data1/av2-goro/DTW/544a8102-0ef5-3044-921e-dc0544370376/map already existed.
# Copying /data1/av2/val/adf9a841-e0db-30ab-b5b3-bf0b61658e1e/map to /data1/av2-goro/PIT/adf9a841-e0db-30ab-b5b3-bf0b61658e1e/map...
# path /data1/av2-goro/PIT/adf9a841-e0db-30ab-b5b3-bf0b61658e1e/map already existed.
# Copying /data1/av2/val/5f8f4a26-59b1-3f70-bcab-b5e3e615d3bc/map to /data1/av2-goro/PIT/5f8f4a26-59b1-3f70-bcab-b5e3e615d3bc/map...
# path /data1/av2-goro/PIT/5f8f4a26-59b1-3f70-bcab-b5e3e615d3bc/map already existed.
# Copying /data1/av2/val/11ba4e81-c26f-3cd1-827d-b6913bcef64e/map to /data1/av2-goro/MIA/11ba4e81-c26f-3cd1-827d-b6913bcef64e/map...
# path /data1/av2-goro/MIA/11ba4e81-c26f-3cd1-827d-b6913bcef64e/map already existed.
# Copying /data1/av2/val/335aabef-269e-3211-a99d-2c3a3a8f8475/map to /data1/av2-goro/MIA/335aabef-269e-3211-a99d-2c3a3a8f8475/map...
# path /data1/av2-goro/MIA/335aabef-269e-3211-a99d-2c3a3a8f8475/map already existed.
# Copying /data1/av2/val/da036982-92bf-36a8-b880-4ccf4e20b74e/map to /data1/av2-goro/WDC/da036982-92bf-36a8-b880-4ccf4e20b74e/map...
# path /data1/av2-goro/WDC/da036982-92bf-36a8-b880-4ccf4e20b74e/map already existed.
# Copying /data1/av2/val/6c932547-4c11-31d7-b8ef-0c16a13dbfc3/map to /data1/av2-goro/PIT/6c932547-4c11-31d7-b8ef-0c16a13dbfc3/map...
# path /data1/av2-goro/PIT/6c932547-4c11-31d7-b8ef-0c16a13dbfc3/map already existed.
# Copying /data1/av2/val/7dbc2eac-5871-3480-b322-246e03d954d2/map to /data1/av2-goro/MIA/7dbc2eac-5871-3480-b322-246e03d954d2/map...
# path /data1/av2-goro/MIA/7dbc2eac-5871-3480-b322-246e03d954d2/map already existed.
# Copying /data1/av2/val/58e82365-03bc-3b2f-b55a-a4ad0e3e792d/map to /data1/av2-goro/MIA/58e82365-03bc-3b2f-b55a-a4ad0e3e792d/map...
# path /data1/av2-goro/MIA/58e82365-03bc-3b2f-b55a-a4ad0e3e792d/map already existed.
# Copying /data1/av2/val/27be7d34-ecb4-377b-8477-ccfd7cf4d0bc/map to /data1/av2-goro/WDC/27be7d34-ecb4-377b-8477-ccfd7cf4d0bc/map...
# path /data1/av2-goro/WDC/27be7d34-ecb4-377b-8477-ccfd7cf4d0bc/map already existed.
# Copying /data1/av2/val/0aa4e8f5-2f9a-39a1-8f80-c2fdde4405a2/map to /data1/av2-goro/PIT/0aa4e8f5-2f9a-39a1-8f80-c2fdde4405a2/map...
# path /data1/av2-goro/PIT/0aa4e8f5-2f9a-39a1-8f80-c2fdde4405a2/map already existed.
# Copying /data1/av2/val/5c0584a3-52a6-3029-b6ff-ca45a19d8aa6/map to /data1/av2-goro/MIA/5c0584a3-52a6-3029-b6ff-ca45a19d8aa6/map...
# path /data1/av2-goro/MIA/5c0584a3-52a6-3029-b6ff-ca45a19d8aa6/map already existed.
# Copying /data1/av2/val/ded5ef6e-46ea-3a66-9180-18a6fa0a2db4/map to /data1/av2-goro/DTW/ded5ef6e-46ea-3a66-9180-18a6fa0a2db4/map...
# path /data1/av2-goro/DTW/ded5ef6e-46ea-3a66-9180-18a6fa0a2db4/map already existed.
# Copying /data1/av2/val/f668074d-d6c6-3ea7-a7b5-aad0a1203b03/map to /data1/av2-goro/DTW/f668074d-d6c6-3ea7-a7b5-aad0a1203b03/map...
# path /data1/av2-goro/DTW/f668074d-d6c6-3ea7-a7b5-aad0a1203b03/map already existed.
# Copying /data1/av2/val/78f7cb5c-9d51-34f0-b356-9b3d83263c75/map to /data1/av2-goro/PIT/78f7cb5c-9d51-34f0-b356-9b3d83263c75/map...
# path /data1/av2-goro/PIT/78f7cb5c-9d51-34f0-b356-9b3d83263c75/map already existed.
# Copying /data1/av2/val/04994d08-156c-3018-9717-ba0e29be8153/map to /data1/av2-goro/PIT/04994d08-156c-3018-9717-ba0e29be8153/map...
# path /data1/av2-goro/PIT/04994d08-156c-3018-9717-ba0e29be8153/map already existed.
# Copying /data1/av2/val/20bcd747-ef60-391a-9f4a-ae99f049c260/map to /data1/av2-goro/MIA/20bcd747-ef60-391a-9f4a-ae99f049c260/map...
# path /data1/av2-goro/MIA/20bcd747-ef60-391a-9f4a-ae99f049c260/map already existed.
# Copying /data1/av2/val/472a240a-10cd-39cd-8681-558f7c7cf868/map to /data1/av2-goro/PIT/472a240a-10cd-39cd-8681-558f7c7cf868/map...
# path /data1/av2-goro/PIT/472a240a-10cd-39cd-8681-558f7c7cf868/map already existed.
# Copying /data1/av2/val/d770f926-bca8-31de-9790-73fbb7b6a890/map to /data1/av2-goro/MIA/d770f926-bca8-31de-9790-73fbb7b6a890/map...
# path /data1/av2-goro/MIA/d770f926-bca8-31de-9790-73fbb7b6a890/map already existed.
# Copying /data1/av2/val/e8c9fd64-fdd2-422d-a2a2-6f47500d1d12/map to /data1/av2-goro/MIA/e8c9fd64-fdd2-422d-a2a2-6f47500d1d12/map...
# path /data1/av2-goro/MIA/e8c9fd64-fdd2-422d-a2a2-6f47500d1d12/map already existed.
# Copying /data1/av2/val/214e388e-cbd7-3dde-a204-d2ec42298808/map to /data1/av2-goro/PIT/214e388e-cbd7-3dde-a204-d2ec42298808/map...
# path /data1/av2-goro/PIT/214e388e-cbd7-3dde-a204-d2ec42298808/map already existed.
# Copying /data1/av2/val/e72ef05c-8b94-3885-a34f-fff3b2b954b4/map to /data1/av2-goro/DTW/e72ef05c-8b94-3885-a34f-fff3b2b954b4/map...
# path /data1/av2-goro/DTW/e72ef05c-8b94-3885-a34f-fff3b2b954b4/map already existed.
# Copying /data1/av2/val/d3ca0450-2167-38fb-b34b-449741cb38f3/map to /data1/av2-goro/DTW/d3ca0450-2167-38fb-b34b-449741cb38f3/map...
# path /data1/av2-goro/DTW/d3ca0450-2167-38fb-b34b-449741cb38f3/map already existed.
# Copying /data1/av2/val/05fa5048-f355-3274-b565-c0ddc547b315/map to /data1/av2-goro/PIT/05fa5048-f355-3274-b565-c0ddc547b315/map...
# path /data1/av2-goro/PIT/05fa5048-f355-3274-b565-c0ddc547b315/map already existed.
# Copying /data1/av2/val/f3cd0d0d-8b71-3266-9732-d9f0d5778eb6/map to /data1/av2-goro/WDC/f3cd0d0d-8b71-3266-9732-d9f0d5778eb6/map...
# path /data1/av2-goro/WDC/f3cd0d0d-8b71-3266-9732-d9f0d5778eb6/map already existed.
# Copying /data1/av2/val/b213af37-7d89-342d-ae39-8a3c72159a01/map to /data1/av2-goro/WDC/b213af37-7d89-342d-ae39-8a3c72159a01/map...
# path /data1/av2-goro/WDC/b213af37-7d89-342d-ae39-8a3c72159a01/map already existed.
# Copying /data1/av2/val/ecbe6def-7560-352c-8822-b2b92613e1e4/map to /data1/av2-goro/DTW/ecbe6def-7560-352c-8822-b2b92613e1e4/map...
# path /data1/av2-goro/DTW/ecbe6def-7560-352c-8822-b2b92613e1e4/map already existed.
# Copying /data1/av2/val/dafe14f5-825c-4e7a-9009-6dfdfdd5b030/map to /data1/av2-goro/MIA/dafe14f5-825c-4e7a-9009-6dfdfdd5b030/map...
# path /data1/av2-goro/MIA/dafe14f5-825c-4e7a-9009-6dfdfdd5b030/map already existed.
# Copying /data1/av2/val/65387aee-4490-38b9-8f4f-1fc43bd4ac06/map to /data1/av2-goro/DTW/65387aee-4490-38b9-8f4f-1fc43bd4ac06/map...
# path /data1/av2-goro/DTW/65387aee-4490-38b9-8f4f-1fc43bd4ac06/map already existed.
# Copying /data1/av2/val/27c03d98-6ac3-38a3-ba5e-102b184d01ef/map to /data1/av2-goro/DTW/27c03d98-6ac3-38a3-ba5e-102b184d01ef/map...
# path /data1/av2-goro/DTW/27c03d98-6ac3-38a3-ba5e-102b184d01ef/map already existed.
# Copying /data1/av2/val/bf382949-3515-3c16-b505-319442937a43/map to /data1/av2-goro/WDC/bf382949-3515-3c16-b505-319442937a43/map...
# path /data1/av2-goro/WDC/bf382949-3515-3c16-b505-319442937a43/map already existed.
# Copying /data1/av2/val/f2576c8a-da9b-450e-88cf-a70af1b0eadf/map to /data1/av2-goro/MIA/f2576c8a-da9b-450e-88cf-a70af1b0eadf/map...
# path /data1/av2-goro/MIA/f2576c8a-da9b-450e-88cf-a70af1b0eadf/map already existed.
# Copying /data1/av2/val/280269f9-6111-311d-b351-ce9f63f88c81/map to /data1/av2-goro/PIT/280269f9-6111-311d-b351-ce9f63f88c81/map...
# path /data1/av2-goro/PIT/280269f9-6111-311d-b351-ce9f63f88c81/map already existed.
# Copying /data1/av2/val/92b900b1-ac4a-3d41-b118-e42c66382c91/map to /data1/av2-goro/ATX/92b900b1-ac4a-3d41-b118-e42c66382c91/map...
# path /data1/av2-goro/ATX/92b900b1-ac4a-3d41-b118-e42c66382c91/map already existed.
# Copying /data1/av2/val/7de2e535-81df-3d5f-a5ca-62e4b940eb54/map to /data1/av2-goro/PIT/7de2e535-81df-3d5f-a5ca-62e4b940eb54/map...
# path /data1/av2-goro/PIT/7de2e535-81df-3d5f-a5ca-62e4b940eb54/map already existed.
# Copying /data1/av2/val/25e5c600-36fe-3245-9cc0-40ef91620c22/map to /data1/av2-goro/PAO/25e5c600-36fe-3245-9cc0-40ef91620c22/map...
# path /data1/av2-goro/PAO/25e5c600-36fe-3245-9cc0-40ef91620c22/map already existed.
# Copying /data1/av2/val/eec284b2-840a-3c75-aa42-04d2e309bbe1/map to /data1/av2-goro/MIA/eec284b2-840a-3c75-aa42-04d2e309bbe1/map...
# path /data1/av2-goro/MIA/eec284b2-840a-3c75-aa42-04d2e309bbe1/map already existed.
# Copying /data1/av2/val/dfc32963-1524-34f4-9f5e-0292f0f223ae/map to /data1/av2-goro/PIT/dfc32963-1524-34f4-9f5e-0292f0f223ae/map...
# path /data1/av2-goro/PIT/dfc32963-1524-34f4-9f5e-0292f0f223ae/map already existed.
# Copying /data1/av2/val/070bbf42-31d3-3aa9-aca4-c262afc9077d/map to /data1/av2-goro/PIT/070bbf42-31d3-3aa9-aca4-c262afc9077d/map...
# path /data1/av2-goro/PIT/070bbf42-31d3-3aa9-aca4-c262afc9077d/map already existed.
# Copying /data1/av2/val/20dd185d-b4eb-3024-a17a-b4e5d8b15b65/map to /data1/av2-goro/DTW/20dd185d-b4eb-3024-a17a-b4e5d8b15b65/map...
# path /data1/av2-goro/DTW/20dd185d-b4eb-3024-a17a-b4e5d8b15b65/map already existed.
# Copying /data1/av2/val/185d3943-dd15-397a-8b2e-69cd86628fb7/map to /data1/av2-goro/MIA/185d3943-dd15-397a-8b2e-69cd86628fb7/map...
# path /data1/av2-goro/MIA/185d3943-dd15-397a-8b2e-69cd86628fb7/map already existed.
# Copying /data1/av2/val/bd90cd1a-38b6-33b7-adec-ba7d4207a8c0/map to /data1/av2-goro/PIT/bd90cd1a-38b6-33b7-adec-ba7d4207a8c0/map...
# path /data1/av2-goro/PIT/bd90cd1a-38b6-33b7-adec-ba7d4207a8c0/map already existed.
# Copying /data1/av2/val/20d47f81-46e8-3adf-a0ca-564fbb5c599d/map to /data1/av2-goro/PIT/20d47f81-46e8-3adf-a0ca-564fbb5c599d/map...
# path /data1/av2-goro/PIT/20d47f81-46e8-3adf-a0ca-564fbb5c599d/map already existed.
# Copying /data1/av2/val/96dd6923-994c-3afe-9830-b15bdfd60f64/map to /data1/av2-goro/WDC/96dd6923-994c-3afe-9830-b15bdfd60f64/map...
# path /data1/av2-goro/WDC/96dd6923-994c-3afe-9830-b15bdfd60f64/map already existed.
# Copying /data1/av2/val/b50c4763-5d1e-37f4-a009-2244aeebabcd/map to /data1/av2-goro/MIA/b50c4763-5d1e-37f4-a009-2244aeebabcd/map...
# path /data1/av2-goro/MIA/b50c4763-5d1e-37f4-a009-2244aeebabcd/map already existed.
# Copying /data1/av2/val/b5a7ff7e-d74a-3be6-b95d-3fc0042215f6/map to /data1/av2-goro/ATX/b5a7ff7e-d74a-3be6-b95d-3fc0042215f6/map...
# path /data1/av2-goro/ATX/b5a7ff7e-d74a-3be6-b95d-3fc0042215f6/map already existed.
# Copying /data1/av2/val/9e9bcfb7-601d-3d80-bc12-ef7025174beb/map to /data1/av2-goro/PIT/9e9bcfb7-601d-3d80-bc12-ef7025174beb/map...
# path /data1/av2-goro/PIT/9e9bcfb7-601d-3d80-bc12-ef7025174beb/map already existed.
# Copying /data1/av2/val/b19f3c1a-a84a-3a2d-8d1b-8a4ae201020b/map to /data1/av2-goro/PIT/b19f3c1a-a84a-3a2d-8d1b-8a4ae201020b/map...
# path /data1/av2-goro/PIT/b19f3c1a-a84a-3a2d-8d1b-8a4ae201020b/map already existed.
# Copying /data1/av2/val/fbd62533-2d32-3c95-8590-7fd81bd68c87/map to /data1/av2-goro/PIT/fbd62533-2d32-3c95-8590-7fd81bd68c87/map...
# path /data1/av2-goro/PIT/fbd62533-2d32-3c95-8590-7fd81bd68c87/map already existed.
# Copying /data1/av2/val/de56b100-508b-3479-81fe-735349f8e8de/map to /data1/av2-goro/ATX/de56b100-508b-3479-81fe-735349f8e8de/map...
# path /data1/av2-goro/ATX/de56b100-508b-3479-81fe-735349f8e8de/map already existed.
# Copying /data1/av2/val/02678d04-cc9f-3148-9f95-1ba66347dff9/map to /data1/av2-goro/PIT/02678d04-cc9f-3148-9f95-1ba66347dff9/map...
# path /data1/av2-goro/PIT/02678d04-cc9f-3148-9f95-1ba66347dff9/map already existed.
# Copying /data1/av2/val/ff0dbfc5-8a7b-3a6e-8936-e5e812e45408/map to /data1/av2-goro/PIT/ff0dbfc5-8a7b-3a6e-8936-e5e812e45408/map...
# path /data1/av2-goro/PIT/ff0dbfc5-8a7b-3a6e-8936-e5e812e45408/map already existed.
# Copying /data1/av2/val/e2e921fe-e489-3656-a0a2-5e17bd399ddf/map to /data1/av2-goro/WDC/e2e921fe-e489-3656-a0a2-5e17bd399ddf/map...
# path /data1/av2-goro/WDC/e2e921fe-e489-3656-a0a2-5e17bd399ddf/map already existed.
# Copying /data1/av2/val/51bbdd4d-3065-34ae-b369-b6e0444f34db/map to /data1/av2-goro/MIA/51bbdd4d-3065-34ae-b369-b6e0444f34db/map...
# path /data1/av2-goro/MIA/51bbdd4d-3065-34ae-b369-b6e0444f34db/map already existed.
# Copying /data1/av2/val/182ba3f7-b89a-36cc-ae40-32a341b0d3e9/map to /data1/av2-goro/MIA/182ba3f7-b89a-36cc-ae40-32a341b0d3e9/map...
# path /data1/av2-goro/MIA/182ba3f7-b89a-36cc-ae40-32a341b0d3e9/map already existed.
# Copying /data1/av2/val/d1395998-7e8a-417d-91e9-5ca6ec045ee1/map to /data1/av2-goro/DTW/d1395998-7e8a-417d-91e9-5ca6ec045ee1/map...
# path /data1/av2-goro/DTW/d1395998-7e8a-417d-91e9-5ca6ec045ee1/map already existed.
# Copying /data1/av2/val/77574006-881f-3bc8-bbb6-81d79cf02d83/map to /data1/av2-goro/MIA/77574006-881f-3bc8-bbb6-81d79cf02d83/map...
# path /data1/av2-goro/MIA/77574006-881f-3bc8-bbb6-81d79cf02d83/map already existed.
# WDC: 126 scenarios
# ATX: 31 scenarios
# MIA: 354 scenarios
# PAO: 22 scenarios
# PIT: 350 scenarios
# DTW: 117 scenarios
# Total number of scenarios: 1000

# %% [markdown]
# ### For each City, aggregate its lanesegment
# * `laneSegmentMap`: A Two-layered hash table
#     * First layer: map [city-name] to laneSegmentMap {}
#     * Second layer: map [lane-id] to `LaneSegment` object
#
# * Later we'll use `laneSegmentMap` to build the route

# %%
laneSegmentMap = {}
dataroot = "/data1/av2-goro"

for city in CITY_NAMES:
    path_to_city = Path(dataroot)/city
    print(f" city: {city}  # logs: {len(os.listdir(path_to_city))}")
    laneSegmentMap[city] = {}
    print(f"    Number of keys in laneSegmentMap: {len(laneSegmentMap)}")
    for log_id in os.listdir(path_to_city):
        avm = create_argoverse_static_map(path_to_city, log_id)
        lane_segment_ids = avm.get_scenario_lane_segment_ids()
        for lane_id in lane_segment_ids:
            laneSegmentMap[city][lane_id] = avm.get_lane_segment_by_id(lane_id)
    print(f"    Total number of lane segments in {city} map: {len(laneSegmentMap[city])}")


# In future, we need to use this laneSegmentMap to query lane segments!
# Below is just to check the type we received.
check_lane_segment_map = False
if check_lane_segment_map:
    for city, laneSegMap in laneSegmentMap.items():
        print(f"City: {city}")
        cnt = 0
        for lane_id, laneSegment in laneSegMap.items():
            if cnt > 10:
                break
            print(f"{lane_id} -> type {type(laneSegment)}")
            cnt += 1
# Out:
#  city: WDC  # logs: 126
#     Number of keys in laneSegmentMap: 1
#     Total number of lane segments in WDC map: 14743
#  city: ATX  # logs: 31
#     Number of keys in laneSegmentMap: 2
#     Total number of lane segments in ATX map: 2859
#  city: MIA  # logs: 354
#     Number of keys in laneSegmentMap: 3
#     Total number of lane segments in MIA map: 45097
#  city: PAO  # logs: 22
#     Number of keys in laneSegmentMap: 4
#     Total number of lane segments in PAO map: 3057
#  city: PIT  # logs: 350
#     Number of keys in laneSegmentMap: 5
#     Total number of lane segments in PIT map: 37105
#  city: DTW  # logs: 117
#     Number of keys in laneSegmentMap: 6
#     Total number of lane segments in DTW map: 16358

# %% [markdown]
# ###  Understanding a `LaneSegment`

# %%
# Select a log_id

# log_id = "07e4fccb-eb2d-31e5-bbcb-6550d0860f64"

def plot_lane_segment_by_id(avm, lane_segment_id, bound_color="black", centerline_color="red"):
    # Plot lane polygon, center-line
    lane_boundaries = avm.get_lane_segment_polygon(lane_segment_id)
    centerlines = avm.get_lane_segment_centerline(lane_segment_id)
    lane_xs, lane_ys = ndarray_to_two_lists(lane_boundaries[:,:2])
    c_xs, c_ys = ndarray_to_two_lists(centerlines[:, :2])

    cx = sum(c_xs) / len(c_xs)
    cy = sum(c_ys) / len(c_ys)

    plt.scatter(lane_xs, lane_ys, color=bound_color, s=8)  # Plot the coordinates
    plt.scatter(c_xs, c_ys, color=centerline_color, s=8)  # Plot the coordinates
    plt.text(cx, cy, str(lane_segment_id), fontsize=12)

    # Plot direction vector
    dir_vector = centerlines[1,:2] - centerlines[0,:2]
    # print(f"    dir_vector.shape {dir_vector.shape}")
    # Plot the second vector
    plt.arrow(centerlines[0,0], centerlines[0,1], dir_vector[0], dir_vector[1], head_width=.5, head_length=1, fc='red', ec='red', label='direction')


# Understanding a lane segment
cityname = log_to_cityname[log_id]
print(f"log_id {log_id} -> cityname: {cityname}")
path_to_city = Path(dataroot) / cityname
avm = create_argoverse_static_map(path_to_city, log_id)
lane_segment_ids = avm.get_scenario_lane_segment_ids()
print(f"Log_id {log_id} has {len(lane_segment_ids)} lane segments")

cur_lane_seg_id = lane_segment_ids[3]
print(f"Current lane id: {cur_lane_seg_id}")
cur_lane_seg = avm.get_lane_segment_by_id(cur_lane_seg_id)

plt.figure()
plot_lane_segment_by_id(avm, cur_lane_seg_id, "blue", "green")

# Predecessors
pred_ids = cur_lane_seg.predecessors
print(f"Predecessor ids: {pred_ids}")
# Successors
succ_ids = cur_lane_seg.successors
print(f"Successors ids: {succ_ids}")
# left neighbor
left_id = cur_lane_seg.left_neighbor_id
print(f"left neighbor ids: {left_id}")
right_id = cur_lane_seg.right_neighbor_id
print(f"right neighbor ids: {right_id}")


# Plot predecessors lane segments
for pred_id in pred_ids:
    if pred_id not in lane_segment_ids:
        print(f"ERROR! pred_id {pred_id} not in this scenario")
        continue
    plot_lane_segment_by_id(avm, pred_id)

# Plot successors lane segments
for suc_id in succ_ids:
    if suc_id not in lane_segment_ids:
        print(f"ERROR! suc_id {suc_id} not in this scenario")    
        continue
    plot_lane_segment_by_id(avm, suc_id)

# Plot left neighbor lane segments
if left_id:
    if left_id not in lane_segment_ids:
        print(f"ERROR! left_id {left_id} not in this scenario")    
    else:
        plot_lane_segment_by_id(avm, left_id)
    
if right_id:
    if right_id not in lane_segment_ids:
        print(f"ERROR! right_id {right_id} not in this scenario")    
    else:     
        plot_lane_segment_by_id(avm, right_id)

plt.xlabel("x(m)")
plt.ylabel("y(m)")
title = f"{log_id}-{cur_lane_seg_id}"
plt.title(title)
plt.grid(True)  # Add grid lines
# Save the plot as a PNG image
plt.savefig(f"{title}.png")
print(f"Map image saved to {title}.png")
# Out:
# log_id d1395998-7e8a-417d-91e9-5ca6ec045ee1 -> cityname: DTW
# Log_id d1395998-7e8a-417d-91e9-5ca6ec045ee1 has 131 lane segments
# Current lane id: 95824852
# Predecessor ids: []
# Successors ids: [95825842]
# left neighbor ids: 95824970
# right neighbor ids: 95824988
# Map image saved to d1395998-7e8a-417d-91e9-5ca6ec045ee1-95824852.png

# %% [markdown]
# ### Extract all centerlines & lane polygons from a single scenario (log_id)
# 1. Get LaneSegments from PaloAlto
# 2. Get center lines coordinates from 1 LaneSegment
# 3. Convert (x,y) to (lat, lng)
# 4. Plot in Google Map

# %%
def get_scenario_all_centerlines(avm):
    """Get center-lines from given LaneSegments
    
    Return:
        centerlines: NDArray of shape (N,2)
    """
    lane_segment_ids = avm.get_scenario_lane_segment_ids()
    # print(f"Number of lane segments in this log: {len(lane_segment_ids)}")

    centerlines = []
    for l_id in lane_segment_ids:
        centerline = avm.get_lane_segment_centerline(l_id) # shape: (10, 3)
        centerlines.append(centerline)
        
    centerlines = np.vstack(centerlines)[:,:2]
    return centerlines



def extract_centerlines_from_log(dataroot, log_id, cityname, frame='wgs84',render_html=False):
    """Extract centerlines from log
    Arguments:
        - log_id of this log data
        - cityname: CityName
    Returns
        - lats: list of latitudes of centerline waypoints
        - lngs: list of longitudes of centerline waypoints
    Additional Output
        - HTML file: (optional) visualize centerlines with Google Satellite Map
    
    """
    avm = create_argoverse_static_map(dataroot, log_id)
    centerlines = get_scenario_all_centerlines(avm)

    city_enum = get_city_enum_from_cityname(cityname)

    if frame=='city':
        xs = centerlines[:,0]
        ys = centerlines[:,1]
        return xs, ys 
    elif frame=='wgs84':
        latlngs_arr = convert_city_coords_to_wgs84(centerlines, city_enum)
        lats, lngs = ndarray_to_two_lists(latlngs_arr)
        if render_html:
            plot_coordinates_on_map(lats, lngs, f"{log_id}.html")
        return lats, lngs

def get_scenario_all_polygons(avm):
    """Get center-lines from given LaneSegments
    
    Return:
        centerlines: NDArray of shape (N,2)
    """
    lane_segment_ids = avm.get_scenario_lane_segment_ids()
    # print(f"Number of lane segments in this log: {len(lane_segment_ids)}")

    polygons = []
    for l_id in lane_segment_ids:
        polygon = avm.get_lane_segment_polygon(l_id) # shape: (10, 3)
        polygons.append(polygon)
        
    polygons = np.vstack(polygons)[:,:2]
    return polygons

def extract_lane_polygons_from_log(dataroot, log_id, cityname, frame='wgs84',render_html=False):
    """Extract centerlines from log
    Arguments:
        - log_id of this log data
        - cityname: CityName
    Returns
        - lats: list of latitudes of centerline waypoints
        - lngs: list of longitudes of centerline waypoints
    Additional Output
        - HTML file: (optional) visualize centerlines with Google Satellite Map
    
    """
    avm = create_argoverse_static_map(dataroot, log_id)
    polygons = get_scenario_all_polygons(avm)
    city_enum = get_city_enum_from_cityname(cityname)

    if frame=='city':
        xs = polygons[:,0]
        ys = polygons[:,1]
        return xs, ys 
    elif frame=='wgs84':
        latlngs_arr = convert_city_coords_to_wgs84(polygons, city_enum)
        lats, lngs = ndarray_to_two_lists(latlngs_arr)        
        if render_html:
            plot_coordinates_on_map(lats, lngs, f"{log_id}.html")
        return lats, lngs

# %% [markdown]
# # Get a rough route using Google Route API
# * Input: a start (lat, lng) and a goal (lat, lng)
# *  Output: a list of waypoints (lat, lng) from start to goal.
#
# ### Pick a pair of (start, goal) location within the log id below:
#
# In our example, the HTML generated for `log_id = "07e4fccb-eb2d-31e5-bbcb-6550d0860f64"` looks like this:
#
# <img src="../imgs/log-id-centerlines.png" width="600">

# %% [markdown]
# I manually compare and pick the following `start` & `goal` locations:
#
# <img src="../imgs/route-start-goal.png" width="600">

# %%
log_id = "07e4fccb-eb2d-31e5-bbcb-6550d0860f64"
cityname = log_to_cityname[log_id]
dataroot = Path("/data1/av2-goro") / cityname

print(f"cityname: {cityname}")
city_enum = get_city_enum_from_cityname(cityname)
print(f"dataroot: {dataroot} city_enum {city_enum}")
# Visualize log_id in HTML
# Plot all centerlines

lats, lngs = extract_centerlines_from_log(dataroot, log_id, cityname, frame='wgs84')
plot_coordinates_on_map(lats, lngs, f"{cityname}-{log_id}.html")

centerline_xs, centerline_ys = extract_centerlines_from_log(dataroot, log_id, cityname, frame='city')
plot_and_save_plt(centerline_ys, centerline_xs, "r", f"{cityname}-{log_id}.png", f"{cityname} (City coordinates)", "x", "y")
# Out:
# cityname: MIA
# dataroot: /data1/av2-goro/MIA city_enum CityName.MIA
# [plot_coordinates_on_map] Map saved to MIA-07e4fccb-eb2d-31e5-bbcb-6550d0860f64.html
# Map image saved to MIA-07e4fccb-eb2d-31e5-bbcb-6550d0860f64.png

# %% [markdown]
# Now, given a trajectory, how do we know which **log HD map** should we take?

# %% [markdown]
# ### Experiments with other locations:
# Try Austin, TX:

# %%
# MIA (the first try)
log_id = "07e4fccb-eb2d-31e5-bbcb-6550d0860f64"
start = ("25.80402823314048", "-80.19421488790299")
goal = ("25.80282667040719", "-80.19514344778023")

# ATX
log_id = "cf6a99cb-b8bc-34d7-bdca-30e50e66cd74"
start = ("30.25531634657375", "-97.70937882886147") # <- ISSUE: NOt able to find near lane segment
goal = ("30.257304300653", "-97.71074332769179")

log_id = "5d8f4b0a-27f8-3889-925f-e9a146a395eb"
start = ("30.25511235534018", "-97.71647936155856")
goal = ("30.25372424274909", "-97.71555619715878")

# PIT
log_id = "d0828f48-3e67-3136-9c70-1f99968c8280"
# with rightmost lane at start
start = ("40.44269600534186", "-79.99873009348677")
goal = ("40.44317176898423", "-80.0003887540773")

# normal case
start = ("40.442901008956895", "-80.00017149083759")
goal = ("40.44270287074084", "-79.9987567768996")

# WDC
log_id = "fdc0f552-4976-36a6-8691-9a8c6a5ba389"
start = ("38.93152962821956", "-76.97222105722838")
goal = ("38.93080484256654", "-76.97114801654325")

# PAO
log_id = "6d3bfbc9-45dc-316e-a94c-a441371d0571"
start = ("37.429150414473156", "-122.14923555120119")
goal = ("37.4296099645031", "-122.14656708639185")


# DTW left - straight - right
log_id = "f7cf93d8-f7bd-3799-8500-fbe842a96f63"
start = ("42.35355983687303", "-83.06596728564301")
goal = ("42.35483247191423", "-83.0658005144748")

# %%
    

# Plot lane boundaries in black, centerlines in red
def visualize_scenario(dataroot, log_id, cityname, frame='city', bound_color="black", centerline_color="red"):

    polygon_xs, polygon_ys = extract_lane_polygons_from_log(dataroot, log_id, cityname, frame='city')
    centerline_xs, centerline_ys = extract_centerlines_from_log(dataroot, log_id, cityname, frame='city')


    # cx = sum(c_xs) / len(c_xs)
    # cy = sum(c_ys) / len(c_ys)

    plt.scatter(polygon_xs, polygon_ys, color=bound_color, s=8)  # Plot the coordinates
    plt.scatter(centerline_xs, centerline_ys, color=centerline_color, s=8)  # Plot the coordinates
    # plt.text(cx, cy, str(lane_segment_id), fontsize=12)

    # Plot direction vector
    # dir_vector = centerlines[1,:2] - centerlines[0,:2]
    # print(f"    dir_vector.shape {dir_vector.shape}")
    # Plot the second vector
    # plt.arrow(centerlines[0,0], centerlines[0,1], dir_vector[0], dir_vector[1], head_width=.5, head_length=1, fc='red', ec='red', label='direction')

cityname = log_to_cityname[log_id]
dataroot = Path("/data1/av2-goro") / cityname
city_enum = get_city_enum_from_cityname(cityname)

# visualize_scenario(log_id)
visualize_scenario(dataroot, log_id, cityname)

centerline_xs, centerline_ys = extract_centerlines_from_log(dataroot, log_id, cityname, frame='city')
polygon_xs, polygon_ys = extract_lane_polygons_from_log(dataroot, log_id, cityname, frame='city')

# %% [markdown]
# ### 1. Get entire rough route from Google Route

# %%
from av2.utils.get_rough_route import get_rough_route
rough_lats, rough_lngs = get_rough_route(start, goal, api_key='AIzaSyBmYtO7rXCbqG02eEzLWb2FgexIve6FmvU')
plot_coordinates_on_map(rough_lats, rough_lngs, "rough-route.html", color='green')
plot_and_save_plt(rough_lats, rough_lngs, color="g", png_file="rough-route.png", xlabel='x(m)', ylabel='y(m)')
# Out:
# start: ('42.35355983687303', '-83.06596728564301')
# goal : ('42.35483247191423', '-83.0658005144748')
#  Sending POST request...
# Getting POST response
# write response.json to ./route_response.json
#     Instruction: Head northeast on W Forest Ave toward Cass Ave
#     Instruction: Turn left at the 1st cross street onto Cass Ave
#     Instruction: Turn right onto W Hancock St
# Destination will be on the right
# Distance: 0.1 mi
# Number of spline points: 196
# Average distance per point: 1.0051020408163265 meter/point
# [plot_coordinates_on_map] Map saved to rough-route.html
# Map image saved to rough-route.png

# %% [markdown]
# Superimpose with centerlines in Miami city coordinates

# %%
# Convert from WGS84 to City coordinatr
points_wgs84 = np.stack((np.asarray(rough_lats), np.asarray(rough_lngs)), axis=1)
points_mia = convert_wgs84_points_to_city_coords(points_wgs84, city_enum) # (N, 2)
rough_xs = points_mia[:, 0]
rough_ys = points_mia[:, 1]
plot_and_save_plt(rough_ys, rough_xs, "green", "rough-route-citycoord.png", xlabel='x(m)', ylabel='y(m)')

"""
Plot all in a single figure
  rough route:     rough_xs, rough_yx
  lane boundaries: lane_bound_xs, lane_bound_ys
  centerlines:     centerline_xs, centerline_ys
"""
png_file=f'{cityname}-{log_id}-method1.png'
plt.figure(f'{cityname} city')
plt.scatter(polygon_xs, polygon_ys, 3, "black")
plt.scatter(centerline_xs, centerline_ys, 3, "red")
plt.scatter(rough_xs, rough_ys, 3, "green")
plt.xlabel('x(m)')
plt.ylabel('y(m)')
plt.title(f'{cityname}-{log_id} (City coordinate)')
plt.grid(True)  # Add grid lines
plt.savefig(png_file)
print(f"Map image saved to {png_file}")
# Out:
# Map image saved to rough-route-citycoord.png
# Map image saved to DTW-f7cf93d8-f7bd-3799-8500-fbe842a96f63-method1.png

# %% [markdown]
# ### 2. Get rough **nodes** from Google API

# %%
# Get rough route 'steps' 
from av2.utils.get_rough_route import Step, Node, Instr
from av2.utils.get_rough_route import get_rough_route_steps, get_latlngs_from_steps

steps = get_rough_route_steps(start, goal, api_key='AIzaSyBmYtO7rXCbqG02eEzLWb2FgexIve6FmvU')

node_lats, node_lngs = get_latlngs_from_steps(steps)
print(f"# node_lats: {len(node_lats)}")
print(f"# node_lngs: {len(node_lngs)}")
plot_coordinates_on_map(node_lats, node_lngs, "rough-route.html", color='green')
plot_and_save_plt(node_lats, node_lngs, color="g", png_file="rough-route.png", xlabel='x(m)', ylabel='y(m)')
# Out:
#  Sending POST request...
# Getting POST response
# write response.json to ./route_response.json
#     Instruction: Head northeast on W Forest Ave toward Cass Ave
#     Instruction: Turn left at the 1st cross street onto Cass Ave
#     Instruction: Turn right onto W Hancock St
# Destination will be on the right
# Number of steps: 3
# step: instruction Instr.GO_STRAIGHT
#     start node: 42.3535411, -83.0659567
#     goal node: 42.3537259, -83.0653571
# step: instruction Instr.TURN_LEFT
#     start node: 42.3537259, -83.0653571
#     goal node: 42.3548135, -83.06597219999999
# step: instruction Instr.TURN_RIGHT
#     start node: 42.3548135, -83.06597219999999
#     goal node: 42.3548721, -83.0658306
# route distance: 0.1 mi
# # node_lats: 6
# # node_lngs: 6
# [plot_coordinates_on_map] Map saved to rough-route.html
# Map image saved to rough-route.png

# %% [markdown]
# ### Search radius
# How far do you want to search for the nearby lane segments

# %%
search_radius = 4
# 0.5 for MIA
# Out:
# 'DTW'

# %% [markdown]
# ## TODO:
# * Figure out how to solve WDC intersection case
# * Refactor the code to make the logic clearer

# %%
# Put these lane segment as "A* goal nodes"
# If 3 lane segments -> plan 2 path
# 2 steps -> 2 path (3 lane segment)
from av2.utils.astar import AstarNode, astar, calc_ls_position
avm = create_argoverse_static_map(dataroot, log_id)

# TODO: Change avm to another class:
# laneSegmentsMap
# get_lane_segment_centerline
# get_nearby_lane_segments
# city & log -> 

plt.figure(f'{cityname} city')
 
def find_target_laneSegment(query_vector, laneSegments, avm):

    matched_ls=laneSegments[0]

    # Use 'direction'
    # Take two successive points as vector
    for ls in laneSegments:
        centerline = avm.get_lane_segment_centerline(ls.id)
        ls_dir_vec = centerline[1,:2] - centerline[0,:2]
        # Plot the second vector
        plt.arrow(centerline[0,0], centerline[0,1], ls_dir_vec[0], ls_dir_vec[1], head_width=2, head_length=2, fc='red', ec='red', label='ls_dir_vec')
        product = np.dot(query_vector, ls_dir_vec)
        if product >= 0:                      
            print(f"        Same dir")
            matched_ls = ls
            # break # hack for WDC test
        else:                     
            print(f"        Opposite dir")
    return matched_ls


def find_rightmost_lane(matched_ls, avm):

    while matched_ls.right_neighbor_id:
        centerline = avm.get_lane_segment_centerline(matched_ls.right_neighbor_id)
        ls_dir_vec = centerline[1,:2] - centerline[0,:2]
        # Plot the second vector
        plt.arrow(centerline[0,0], centerline[0,1], ls_dir_vec[0], ls_dir_vec[1], head_width=2, head_length=2, fc='red', ec='red', label='ls_dir_vec')

        product = np.dot(step_vec, ls_dir_vec)

        if product >= 0:                      
            print(f"        Same dir")
            print(f"        right_neighbor_id: {matched_ls.right_neighbor_id}")
            matched_ls = avm.get_lane_segment_by_id(matched_ls.right_neighbor_id)                                                
        else:                     
            print(f"        Opposite dir")
            break    
    return matched_ls

def find_leftmost_lane(matched_ls, avm):
    while matched_ls.left_neighbor_id:
        centerline = avm.get_lane_segment_centerline(matched_ls.left_neighbor_id)
        ls_dir_vec = centerline[1,:2] - centerline[0,:2]
        # Plot the second vector
        plt.arrow(centerline[0,0], centerline[0,1], ls_dir_vec[0], ls_dir_vec[1], head_width=2, head_length=2, fc='red', ec='red', label='ls_dir_vec')

        product = np.dot(step_vec, ls_dir_vec)

        if product >= 0:                      
            print(f"        Same dir")
            print(f"        left_neighbor id: {matched_ls.left_neighbor_id}")
            matched_ls = avm.get_lane_segment_by_id(matched_ls.left_neighbor_id)                               
            # break
        else:                     
            print(f"    Opposite dir")
            break    
    return matched_ls

# A list of step: steps
# For each step
#   1. Convert 'start' & end node to city xy
#   2. Find nearby lane segment to start & end
nodes = []
for i, step in enumerate(steps):

    lane_polygon_xs = []
    lane_polygon_ys = []
    centerline_xs = []
    centerline_ys = []


    start_latlng = np.array((step.start.lat, step.start.lng))
    goal_latlng = np.array((step.goal.lat, step.goal.lng))
    # query_latlng = np.stack((start_latlng, goal_latlng), axis=0) 
    start_x, start_y = convert_wgs84_points_to_city_coords(start_latlng.reshape(1,2), city_enum)[0]
    goal_x, goal_y = convert_wgs84_points_to_city_coords(goal_latlng.reshape(1,2), city_enum)[0]
    # Find nearby lane segment:

    # vector for this step: from start to goal
    step_vec = np.array((goal_x-start_x, goal_y-start_y))
    plt.arrow(start_x, start_y, step_vec[0], step_vec[1], head_width=2, head_length=2, fc='blue', ec='blue', label='step_vec')

    if i==0:
        query_st = np.array((start_x, start_y))
        lss = avm.get_nearby_lane_segments(query_st, search_radius_m=search_radius)
        print(f"step {i} # ls near start: {len(lss)} instr: {step.instruction}")
        # TODO: How to pick the correct "lane segment"?
        if len(lss)>0:

            # 1. Find 'target_ls' based on vector correction
            matched_ls = find_target_laneSegment(step_vec, lss, avm)

            # 2. Check 'next step' instruction
            # Then check instruction:
            next_step = steps[i+1]
            if next_step.instruction == Instr.TURN_RIGHT:
                print(f"    next turn right -> Should pick rightmost lane")
                matched_ls = find_rightmost_lane(matched_ls, avm)

            elif next_step.instruction == Instr.TURN_LEFT:
                print(f"    next turn left -> Pick leftmost lane")
                matched_ls = find_leftmost_lane(matched_ls, avm)
            else:
                print(f"use the most center lane (use leftmost for now)")

            ls_pos = calc_ls_position(avm, matched_ls.id)
            nodes.append(AstarNode(matched_ls.id, ls_pos))
            print(f"    Add A* node: {matched_ls.id} pos: {ls_pos}")

            # ------ visualization purposes ------------ 
            lane_polygon_xs.extend(matched_ls.polygon_boundary[:,0])
            lane_polygon_ys.extend(matched_ls.polygon_boundary[:,1])
            centerline = avm.get_lane_segment_centerline(matched_ls.id)
            centerline_xs.extend(centerline[:,0])
            centerline_ys.extend(centerline[:,1])              
        else:
            print(f"    Error! No lane segments near {query_st} within {search_radius} meter")

        # ------ visualization purposes ------------ 
        for j, ls in enumerate(lss):
            lane_polygon_xs.extend(ls.polygon_boundary[:,0])
            lane_polygon_ys.extend(ls.polygon_boundary[:,1])
            # centerline = avm.get_lane_segment_centerline(ls.id)
            # centerline_xs.extend(centerline[:,0])
            # centerline_ys.extend(centerline[:,1])   
    elif i < len(steps)-1:
        # Middle step: use the 'mid point' between start-goal node as query_pt
        # query_st = np.array((start_x, start_y))
        query_pt = np.array(((start_x+goal_x)/2, (start_y+goal_y)/2))
        lss = avm.get_nearby_lane_segments(query_pt, search_radius_m=search_radius)
        print(f"step {i} # ls near start: {len(lss)} instr: {step.instruction}")
        # TODO: How to pick the correct "lane segment"?
        if len(lss)>0:

            # 1. Find 'target_ls' based on vector correction
            matched_ls = find_target_laneSegment(step_vec, lss, avm)

            # 2. Check 'next step' instruction
            # Then check instruction:
            next_step = steps[i+1]
            if next_step.instruction == Instr.TURN_RIGHT:
                print(f"    next turn right -> Should pick rightmost lane")
                matched_ls = find_rightmost_lane(matched_ls, avm)

            elif next_step.instruction == Instr.TURN_LEFT:
                print(f"    next turn left -> Pick leftmost lane")
                matched_ls = find_leftmost_lane(matched_ls, avm)
            else:
                print(f"use the most center lane (use leftmost for now)")

            ls_pos = calc_ls_position(avm, matched_ls.id)
            nodes.append(AstarNode(matched_ls.id, ls_pos))
            print(f"    Add A* node: {matched_ls.id} pos: {ls_pos}")

            # ------ visualization purposes ------------ 
            lane_polygon_xs.extend(matched_ls.polygon_boundary[:,0])
            lane_polygon_ys.extend(matched_ls.polygon_boundary[:,1])
            centerline = avm.get_lane_segment_centerline(matched_ls.id)
            centerline_xs.extend(centerline[:,0])
            centerline_ys.extend(centerline[:,1])              
        else:
            print(f"    Error! No lane segments near {query_pt} within {search_radius} meter")

        # ------ visualization purposes ------------ 
        for j, ls in enumerate(lss):
            lane_polygon_xs.extend(ls.polygon_boundary[:,0])
            lane_polygon_ys.extend(ls.polygon_boundary[:,1])
            # centerline = avm.get_lane_segment_centerline(ls.id)
            # centerline_xs.extend(centerline[:,0])
            # centerline_ys.extend(centerline[:,1])         

        """Only add the goal node for the last step"""
    elif i == len(steps)-1:
        query_gl = np.array((goal_x, goal_y))
        lss = avm.get_nearby_lane_segments(query_gl, search_radius_m=search_radius)    
        print(f"step {i} # ls near goal: {len(lss)}")
        plt.arrow(start_x, start_y, step_vec[0], step_vec[1], head_width=2, head_length=2, fc='green', ec='green', label='goal_vec')

        if len(lss)>0:
            matched_ls = find_target_laneSegment(step_vec, lss, avm)       

            # ls = lss[0]
            ls_pos = calc_ls_position(avm, matched_ls.id)
            nodes.append(AstarNode(matched_ls.id, ls_pos))
            print(f"    Add A* node: {matched_ls.id} pos: {ls_pos}")

            # ------ visualization purposes ------------ 
            lane_polygon_xs.extend(matched_ls.polygon_boundary[:,0])
            lane_polygon_ys.extend(matched_ls.polygon_boundary[:,1])
            centerline = avm.get_lane_segment_centerline(matched_ls.id)
            centerline_xs.extend(centerline[:,0])
            centerline_ys.extend(centerline[:,1])                
        else:
            print(f"    Error! No lane segments near {query_gl} within {search_radius} meter")

        # ------ visualization purposes ------------ 
        for ls in lss:
            lane_polygon_xs.extend(ls.polygon_boundary[:,0])
            lane_polygon_ys.extend(ls.polygon_boundary[:,1])   
            # centerline = avm.get_lane_segment_centerline(ls.id)
            # centerline_xs.extend(centerline[:,0])
            # centerline_ys.extend(centerline[:,1]) 
            # print(f"    ls id: {ls.id}")
            # print(f"    predecessors: {ls.predecessors}")
            # print(f"    successors: {ls.successors}")

    # Plot:
    png_file='mia-log-overlap.png'

    plt.scatter(lane_polygon_xs, lane_polygon_ys, 6, "black")
    plt.scatter(centerline_xs, centerline_ys, 6, "red")
    plt.scatter(start_x, start_y, 12, "green")
    plt.scatter(goal_x, goal_y, 12, "green")
    plt.xlabel('x(m)')
    plt.ylabel('y(m)')
    plt.title(f'{cityname} log (City coordinate)')
    plt.grid(True)  # Add grid lines
# Out:
# step 0 # ls near start: 6 instr: Instr.GO_STRAIGHT
#         Same dir
#         Same dir
#         Same dir
#         Same dir
#         Same dir
#         Same dir
#     next turn left -> Pick leftmost lane
#         Same dir
#         left_neighbor id: 86832576
#         Same dir
#         left_neighbor id: 86832591
#         Same dir
#         left_neighbor id: 86832631
#     Add A* node: 86832631 pos: (9195.5825, 5741.120000000001)
# step 1 # ls near start: 4 instr: Instr.TURN_LEFT
#         Same dir
#         Opposite dir
#         Same dir
#         Opposite dir
#     next turn right -> Should pick rightmost lane
#     Add A* node: 86833444 pos: (9208.130000000001, 5805.765)
# step 2 # ls near goal: 4
#         Opposite dir
#         Same dir
#         Opposite dir
#         Same dir
#     Add A* node: 86832288 pos: (9189.891569711508, 5867.209867520942)

# %% [markdown]
# Run A* to find the path between each A* node pair

# %% [markdown]
# ## TODO:
# * Instead of passing `avmap` , should pass our newly built data structure: `laneSegmentMap`
# * Given a `city` and `start`, `goal` node, find the optimal path
#
# * Issue in WDC: After the first left turn, need to switch to "right lane segment".
# * How to do it? Should add "intermediate target lane segment"
#
# * Intersection: Need to look at **instruction**

# %%
def find_nodes_route(avmap, nodes):
    """
    Args: 
        avmap: ArgoverseStaticMap for this scenario
        nodes: a list of nodes to be visit
                for every pair (i, i+1):
                    nodes[i] is start
                    nodes[i+1] is goal node
    Return:
        ls_ids: a list of [lane_segment_id]

    """    
    ls_ids = []
    for i, node in enumerate(nodes):
        if i < len(nodes)-1:
            print(f"Find path from node {i} -> {i+1}")
            start_node = nodes[i]
            goal_node = nodes[i+1]
            laneSegment_ids = astar(avmap, start_node, goal_node)
            # Note: need to remove duplicated node.
            # Remove the first node if i>0

            if i>0:
                laneSegment_ids = laneSegment_ids[1:]

            ls_ids.extend(laneSegment_ids)
    return ls_ids

# ------------ Below is the execution ----------------- #
print(f"Number of nodes: {len(nodes)}")
for node in nodes:
    print(f"    node id: {node.lsid}")
ls_ids = find_nodes_route(avm, nodes)
print(f"Total number of lane ids: {len(ls_ids)}")
print(f"list of lane segment ids: {ls_ids}")
# Out:
# Number of nodes: 3
#     node id: 86832631
#     node id: 86833444
#     node id: 86832288
# Find path from node 0 -> 1
# Find path from node 1 -> 2
# Total number of lane ids: 11
# list of lane segment ids: [86832631, 86834016, 86833267, 86834258, 86833396, 86833444, 86833404, 86832302, 86832113, 86832376, 86832288]

# %%
def retrieve_centerlines(avmap, ls_ids):
    """
        Given a list of lane segment ids
        Returns:
            a list of centerlines.
            Each item is a list of waypoitns corresponds to the centerline of a lane segment
            A centerline is a Ndarray of shape (N, 3)
    """
    centerlines = []
    for ls_id in ls_ids:
        centerlines.append(avmap.get_lane_segment_centerline(ls_id))
    return centerlines


import scipy.interpolate

def generate_spline_curve(v1, v2, num_points=7):
    """
    Generates a cubic spline curve between two vectors.

    Parameters:
    v1 (array-like): The starting vector (x1, y1).
    v2 (array-like): The ending vector (x2, y2).
    num_points (int): Number of points in the spline curve.

    Returns:
    np.ndarray: Array of points representing the spline curve.
    """
    # Ensure v1 and v2 are numpy arrays
    v1 = np.array(v1)
    v2 = np.array(v2)

    # Create parameter values for the start and end points
    t = np.array([0, 1])

    # Create the x and y coordinates
    x = np.array([v1[0], v2[0]])
    y = np.array([v1[1], v2[1]])

    # Generate spline
    cs_x = scipy.interpolate.CubicSpline(t, x)
    cs_y = scipy.interpolate.CubicSpline(t, y)

    # Generate points along the spline
    t_fine = np.linspace(0, 1, num_points)
    x_fine = cs_x(t_fine)
    y_fine = cs_y(t_fine)

    # Combine x and y into points
    points = np.vstack((x_fine, y_fine)).T

    return points


import math 

def connect_ls_centerlines(avmap, ls_ids, centerlines):
    """ Given a list of lane segment ids,
        Connect the lane segment centerlines
    
        Returns:
            route_centerlines: a Numpy array of shape (N, 2)
    """
    route_centerlines = np.empty((0,2))

    plt.figure()
    skip = False
    for i, ls_id in enumerate(ls_ids):

        if skip:
            # reset the flag
            skip = False
            continue

        centerline = centerlines[i]
        cxs, cys = ndarray_to_two_lists(centerline[:,:2])
        successor_ids = avmap.get_lane_segment_successor_ids(ls_id)

        if i < len(ls_ids)-1:
            if ls_ids[i+1] in successor_ids:
                route_centerlines = np.concatenate((route_centerlines, centerline[:,:2]))
                plt.scatter(cxs, cys, color="black", s=8)      
            else:
                if ls_ids[i+1] == avmap.get_lane_segment_left_neighbor_id(ls_id):
                    print(f"    next lane is left neighbor")
                    plt.scatter(cxs, cys, color="green", s=8)
                else:
                    print(f"    next lane is right neighbor")
                    plt.scatter(cxs, cys, color="red", s=8)

                # Special case: two consecutive left/right neighbor
                next_succ_ids = avmap.get_lane_segment_successor_ids(ls_ids[i+1])
                if i < len(ls_ids)-2 and ls_ids[i+2] not in next_succ_ids:
                    print(f"Special case!")
                    # Skip next centerline. Directly pick centerlines[i+2]
                    cur_end_index = math.ceil(0.3*len(centerline))
                    cur_centerline = centerline[:cur_end_index,:]
      
                    next_start_index = math.ceil(0.6*len(centerlines[i+2]))
                    next_centerline = centerlines[i+2][next_start_index:,:]
                    v1 = [cur_centerline[-2],cur_centerline[-1]]
                    spline_curve = generate_spline_curve(cur_centerline[-1], next_centerline[0])
                    # spline_curve = get_spline(cur_centerline[-1], next_centerline[0])
                    # Need to change the starting point of the next next centerline!
                    centerlines[i+2] = centerlines[i+2][next_start_index:,:]
                    
                    route_centerlines = np.concatenate((route_centerlines, cur_centerline[:,:2]))
                    route_centerlines = np.concatenate((route_centerlines, spline_curve[:,:2]))                    
                    
                    skip = True
                    
                else:
                    print(f"it's left or right neighbor. Need to do spline connection!")
                    # retrieve two centerlines
                    # take cur[0:75%] and next[25%, -1]
                    cur_end_index = math.ceil(0.3*len(centerline))
                    # print(f"cur # pt {len(centerline)} cur_end_index: {cur_end_index}")
                    cur_centerline = centerline[:cur_end_index,:]
      
                    next_start_index = math.ceil(0.6*len(centerlines[i+1]))
                    # print(f"next # pt {len(centerlines[i+1])} next_start_index: {next_start_index}")
                    next_centerline = centerlines[i+1][next_start_index:,:]
                    
                    # Add cubic spline between cur & next
                    spline_curve = generate_spline_curve(cur_centerline[-1], next_centerline[0])
                    # spline_curve = get_spline(cur_centerline[-1], next_centerline[0])
                    # Need to change the starting point of the next centerline!
                    centerlines[i+1] = centerlines[i+1][next_start_index:,:]
                    
                    route_centerlines = np.concatenate((route_centerlines, cur_centerline[:,:2]))
                    route_centerlines = np.concatenate((route_centerlines, spline_curve[:,:2]))

        else: # last segment
            plt.scatter(cxs, cys, color="black", s=8)   
            route_centerlines = np.concatenate((route_centerlines, centerline[:,:2]))

    print(f"Number of waypoints in route: {len(route_centerlines)}")
    return route_centerlines



centerlines = retrieve_centerlines(avm, ls_ids)
route_centerlines = connect_ls_centerlines(avm, ls_ids, centerlines)

plt.clf()
route_xs, route_ys = zip(*route_centerlines)
plot_and_save_plt(route_ys, route_xs, "green", "corrected-route-citycoord.png", xlabel='x(m)', ylabel='y(m)')
# Out:
# Number of waypoints in route: 110
# Map image saved to corrected-route-citycoord.png

# %% [markdown]
# Convert corrected route back to WGS84 (lat,lng) and superimpose it with Google Map

# %%
route_lats = []
route_lngs = []
for waypoint in route_centerlines:
    lat, lng = convert_city_coords_to_wgs84(waypoint.reshape(-1,2), cityname)[0]
    route_lats.append(lat)
    route_lngs.append(lng)

plot_coordinates_on_map(route_lats, route_lngs, f"route-{cityname}-{log_id}.html")
plot_route_and_correct(rough_lats, rough_lngs, route_lats, route_lngs, f"route-ba-{cityname}-{log_id}.html")
# Out:
# [plot_coordinates_on_map] Map saved to route-DTW-f7cf93d8-f7bd-3799-8500-fbe842a96f63.html
# [plot_route_and_correct] Map saved to route-ba-DTW-f7cf93d8-f7bd-3799-8500-fbe842a96f63.html

# %% [markdown]
# # Old functions

# %% [markdown]
# ### Read `/data1/av2-datasets/train` and extract `log-ids`
# 1. Build hash table `log_to_cityname`: **key**: `log-id` -> **Value**: `CityName`
# 2. `city_logids`: key: str -> val: [str] list of log ids
# 3. Save 6 lists of `log-ids`

# %%
# path to where the logs live
category="train" # train, val, test
dataroot = f"/data1/av2/{category}"

print(f"Loading dataset: {dataroot}")

# unique log identifier
# log_id = "adcf7d18-0510-35b0-a2fa-b4cea13a6d76"
log_id = "00a6ffc1-6ce9-3bc3-a060-6006e9893a1a"
# Out:
# Loading dataset: /data1/av2/train

# %%
"""
Writ a class: AV2HDMap
members:
- centerlines - city coordinates (x, y)
              - wgs84 coords: (lat, lng)

- lane_boundary - city coordinates (x, y)
              - wgs84 coords: (lat, lng)

- centerlines - city coordinates (x, y)
              - wgs84 coords: (lat, lng)

                            
"""

def write_txt(lats, lngs, filename='latlngs.txt'):
    file = open(filename,'w')
    for lat, lng in zip(lats, lngs):
        file.write(str(lat) + " " + str(lng) +"\n")
    file.close()

# %% [markdown]
# ### Plot the centerlines of the first five logs in Miami.

# %%
cityname = "MIA"
city_lats = []
city_lngs = []
centerline_xs = []
centerline_ys = []
city_logids[cityname] = sorted(city_logids[cityname])
path_to_cityname=Path(dataroot)/cityname
for idx, log_id in enumerate(city_logids[cityname]):
    # if idx <=2:
    #     continue
    if idx >= 5:
        break
    # print(f"log_id {log_id}")
    # print(f"Get centerline for log id: {log_id}")
    lats, lngs = extract_centerlines_from_log(path_to_cityname, log_id, cityname, frame='wgs84')
    city_lats.extend(lats)
    city_lngs.extend(lngs)
    xs, ys = extract_centerlines_from_log(path_to_cityname, log_id, cityname, frame='city')
    centerline_xs.extend(xs)
    centerline_ys.extend(ys)

plot_and_save_plt(centerline_ys, centerline_xs, "r", f"{cityname}-{len(city_logids[cityname])}.png", f"{cityname} (City coordinates)", "x", "y")
plot_coordinates_on_map(city_lats, city_lngs, f"{cityname}-full.html")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 15
#      12     break
#      13 # print(f"log_id {log_id}")
#      14 # print(f"Get centerline for log id: {log_id}")
# ---> 15 lats, lngs = extract_centerlines_from_log(path_to_cityname, log_id, cityname, frame='wgs84')
#      16 city_lats.extend(lats)
#      17 city_lngs.extend(lngs)
#
# Cell In[36], line 32, in extract_centerlines_from_log(dataroot, log_id, cityname, frame, render_html)
#      20 def extract_centerlines_from_log(dataroot, log_id, cityname, frame='wgs84',render_html=False):
#      21     """Extract centerlines from log
#      22     Arguments:
#      23         - log_id of this log data
#    (...)
#      30
#      31     """
# ---> 32     avm = create_argoverse_static_map(dataroot, log_id)
#      33     centerlines = get_scenario_all_centerlines(avm)
#      35     city_enum = get_city_enum_from_cityname(cityname)
#
# File ~/planning/av2-api/src/av2/utils/utils.py:275, in create_argoverse_static_map(dataroot, log_id)
#     272 def create_argoverse_static_map(dataroot, log_id):
#     273     # args = Namespace(**{"dataroot": Path(dataroot), "log_id": Path(log_id)})
#     274     log_map_dirpath = Path(dataroot) / log_id / "map"
# --> 275     avm = ArgoverseStaticMap.from_map_dir(log_map_dirpath, build_raster=False)
#     276     return avm
#
# File ~/planning/av2-api/src/av2/map/map_api.py:406, in ArgoverseStaticMap.from_map_dir(cls, log_map_dirpath, build_raster)
#     404 vector_data_fnames = sorted(log_map_dirpath.glob("log_map_archive_*.json"))
#     405 if not len(vector_data_fnames) == 1:
# --> 406     raise RuntimeError(
#     407         f"JSON file containing vector map data is missing (searched in {log_map_dirpath})"
#     408     )
#     409 vector_data_fname = vector_data_fnames[0].name
#     411 vector_data_json_path = log_map_dirpath / vector_data_fname
#
# RuntimeError: JSON file containing vector map data is missing (searched in /data1/av2-goro/DTW/MIA/022af476-9937-3e70-be52-f65420d52703/map)

# %% [markdown]
# ### Plot lane polygons (boundaries)

# %%
# Take the first 10 logs
city_lats = []
city_lngs = []
polygon_xs = []
polygon_ys = []
city_logids[cityname] = sorted(city_logids[cityname])
path_to_cityname=Path(dataroot)/cityname
for idx, log_id in enumerate(city_logids[cityname]):
    # if idx <=2:
        # continue
    if idx >= 5:
        break
    lats, lngs = extract_lane_polygons_from_log(path_to_cityname, log_id, cityname, frame='wgs84')
    city_lats.extend(lats)
    city_lngs.extend(lngs)
    xs, ys = extract_lane_polygons_from_log(path_to_cityname, log_id, cityname, frame='city')
    polygon_xs.extend(xs)
    polygon_ys.extend(ys)

plot_and_save_plt(polygon_ys, polygon_xs, "black", f"{cityname}-{len(city_logids[cityname])}-polygon.png", f"{cityname} lane polygons (City coordinates)", "x", "y")
plot_coordinates_on_map(city_lats, city_lngs, f"{cityname}-polygon.html")
# Out:
# Map image saved to MIA-254-polygon.png
# [plot_coordinates_on_map] Map saved to MIA-polygon.html

# %% [markdown]
# Plot centerlines and polygons together

# %%
# Plot centerlines and lane polygons
png_file=f'{cityname}-log-overlap.png'
plt.figure(f"{cityname}")
plt.scatter(polygon_xs, polygon_ys, 3, "black")
plt.scatter(centerline_xs, centerline_ys, 3, "red")
# plt.scatter(rough_xs, rough_ys, 3, "green")
plt.xlabel('x(m)')
plt.ylabel('y(m)')
plt.title(f'{cityname} log (City coordinate)')
plt.grid(True)  # Add grid lines
# Save the plot as a PNG image
# plt.show()
plt.savefig(png_file)
print(f"Map image saved to {png_file}")
# Out:
# Map image saved to MIA-log-overlap.png

# %%
import json
import os
from pathlib import Path

def get_log_ids(directory):
    log_ids = []
    # Iterate over the contents of the directory
    for entry in os.listdir(directory):
        # Join the directory path with the entry name to get the full path
        full_path = os.path.join(directory, entry)
        # Check if the entry is a directory
        if os.path.isdir(full_path):
            log_ids.append(entry)
    return log_ids

"""
    ATX = "ATX"  # Austin, Texas
    DTW = "DTW"  # Detroit, Michigan
    MIA = "MIA"  # Miami, Florida
    PAO = "PAO"  # Palo Alto, California
    PIT = "PIT"  # Pittsburgh, PA
    WDC = "WDC"  # Washington, DC

"""
log_to_cityname = {}
city_logids = {} # key: str -> val: [str] list of log ids

log_ids = get_log_ids(dataroot)
for log_id in log_ids:
    cityname = extract_cityname_from_log(dataroot, log_id)
    # print(f"    Map {log_id} -> CityName {cityname}")
    log_to_cityname[log_id] = cityname
    if cityname in city_logids:
        city_logids[cityname].append(log_id)
    else:
        city_logids[cityname] = [log_id]
    
print(f"Number of cities: {len(city_logids)}")
for key, value in city_logids.items():
    print(f"city: {key} number of log ids {len(value)}")
# Out:
# Number of cities: 6
# city: MIA number of log ids 254
# city: PIT number of log ids 247
# city: ATX number of log ids 25
# city: DTW number of log ids 75
# city: WDC number of log ids 87
# city: PAO number of log ids 12
